# %% [markdown]
# Video referencia: https://www.youtube.com/watch?v=tsVWd6I5nuk

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Loading Data

# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Model Training

# %% [markdown]
# # Performance Metrics

# %% [markdown]
# # Utilizando exemplo encontrado em uma artigo no medium para testar varios exemplos de ML

# %%
import pandas as pd
import numpy as np

# %%
uri = 'https://raw.githubusercontent.com/sthemonica/alura-voz/main/Dados/Telco-Customer-Churn.json'

# %%
dados = pd.read_json(uri)

# %%
customer = dados['customer'].apply(pd.Series)
phone = dados['phone'].apply(pd.Series)
internet = dados['internet'].apply(pd.Series)
account = dados['account'].apply(pd.Series)
charges = account['Charges'].apply(pd.Series)
churn = dados['Churn']

# %%
customerID = pd.DataFrame(dados['customerID'])
dataframe = customerID.join([customer, phone, internet, account, charges, churn])
dataframe.drop(['Charges'], axis=1, inplace=True)

# %%
quantitativas = dataframe[['tenure', 'Monthly', 'Total']].astype({'tenure' : 'int',
                                                                   'Monthly' : 'float',
                                                                   'Total' : 'float'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-78dc441bf449> in <module>
#       1 quantitativas = dataframe[['tenure', 'Monthly', 'Total']].astype({'tenure' : 'int',
#       2                                                                    'Monthly' : 'float',
# ----> 3                                                                    'Total' : 'float'})
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5797                 if col_name in dtype:
#    5798                     results.append(
# -> 5799                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5800                     )
#    5801                 else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
# ...

# %%
from sklearn.model_selection import train_test_split

SEED = 0
np.random.seed(SEED)

treino_x, teste_x, treino_y, teste_y = train_test_split(x,
                                                        y,
                                                        test_size=0.3,
                                                        random_state = SEED)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ae06aa34c0b3> in <module>
#       4 np.random.seed(SEED)
#       5
# ----> 6 treino_x, teste_x, treino_y, teste_y = train_test_split(x,
#       7                                                         y,
#       8                                                         test_size=0.3,
#
# NameError: name 'x' is not defined

# %%
LR_params = [{'C':0.01}, 
             {'C':0.1}, 
             {'C':1}, 
             {'C':10}]

DTC_params = [{'criterion': 'gini'}, 
              {'criterion': 'entropy'}, 
              {'max_depth': 2},
              {'max_depth': 3},
              {'max_depth': 5},
              {'max_depth': 10}]

RFC_params = [{'criterion': 'gini'}, 
              {'criterion': 'entropy'},
              {'max_depth': 2},
              {'max_depth': 3},
              {'max_depth': 5},
              {'max_depth': 10}]

KNN_params = [{'n_neighbors':3}, 
              {'n_neighbors':5}]

BNB_params = [{'binarize':(np.median(treino_x))}]

SVC_params = [{'C':0.01}, 
              {'C':0.1}, 
              {'C':1}, 
              {'C':10}]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bebb38c728d0> in <module>
#      21               {'n_neighbors':5}]
#      22
# ---> 23 BNB_params = [{'binarize':(np.median(treino_x))}]
#      24
#      25 SVC_params = [{'C':0.01},
#
# NameError: name 'treino_x' is not defined

# %% [markdown]
# # Analisando as notas em geral

# %%
import pandas as pd

# %%
notas = pd.read_csv('ratings.csv', sep=',')

# %%
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns = ['usuarioId', 'filmeId', 'nota', 'momento']
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas['nota']
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas['nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['nota'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
print(notas['nota'].mean())  # media
print(notas['nota'].median())  # mediana
# Out:
# 3.501556983616962
# 3.5

# %%
notas.nota
# Out:
# 0         4.0
# 1         4.0
# 2         4.0
# 3         5.0
# 4         5.0
#          ...
# 100831    4.0
# 100832    5.0
# 100833    5.0
# 100834    5.0
# 100835    3.0
# Name: nota, Length: 100836, dtype: float64

# %%
notas.nota.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: nota, dtype: float64

# %%
notas.nota.plot(kind='hist')

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(notas.nota)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Olhando os filmes

# %%
filmes = pd.read_csv('movies.csv')

# %%
filmes.columns = ['filmeId', 'titulo', 'generos']
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %% [markdown]
# # Analisando algumas notas especificas por filme

# %%
notas.query('filmeId==1').nota.mean()  # filtra linhas com querry, depois filtra coluna
# Out:
# 3.9209302325581397

# %%
notas.query('filmeId==2').nota.mean()
# Out:
# 3.4318181818181817

# %%
medias_por_filme = notas.groupby('filmeId').mean()['nota']

# %%
medias_por_filme.plot(kind='hist')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 8))
sns.boxplot(y=medias_por_filme)

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
sns.distplot(medias_por_filme, bins=10)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(medias_por_filme)
plt.title('Histograma das médias dos filmes')
# Out:
# Text(0.5, 1.0, 'Histograma das médias dos filmes')

# %% [markdown]
# # The movie DataBase

# %%
tmdb = pd.read_csv('tmdb_5000_movies.csv')
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.original_language.unique()  # categorica nominal
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
# primeiro grau (fundamental)
# segundo grau (medio)
# terceiro grau (faculdade)
# 1 grau < 2 grau < 3 grau  # categorica ordinal

# %%
# budget => orcamento => quantitativa continuo

# %%
# quantidade de votos => 1, 2, 3, 4, nao tem 2.5 votos
# notas do movielens => 0.5, 1, 1.5, ... , 5, nao tem 2.7

# %%
contagem_de_lingua = tmdb['original_language'].value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ['original_language', 'total']
contagem_de_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
sns.barplot(x='original_language', y='total', data = contagem_de_lingua)

# %%
sns.catplot(x='original_language', kind='count', data=tmdb)

# %%
# print(sns.__version__)  => na aula a versão é a 0.7

# %%
plt.pie(contagem_de_lingua['total'], labels=contagem_de_lingua['original_language'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7a6222a8d0>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'zh'),
#   Text(1.0773191105706255, -0.22222406260195313, 'de'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ru'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ko'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'nl'),
#   Text(1.0990363161210686, -0.04603450713357274, 'fa'),
# ...

# %%
total_por_lingua = tmdb['original_language'].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc['en']
total_do_resto = total_geral - total_de_ingles
print(total_de_ingles, total_do_resto)
# Out:
# 4505 298

# %%
dados = {
    'lingua' : ['ingles', 'outros'],
    'total' : [total_de_ingles, total_do_resto]
}
dados = pd.DataFrame(dados)
sns.barplot(x='lingua', y='total', data=dados)

# %%
plt.pie(dados['total'], labels=dados['lingua'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7a61a12610>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'ingles'),
#   Text(1.0791697511565306, -0.2130555049482467, 'outros')])

# %%
total_por_lingua_de_outros_filmes = tmdb.query('original_language != "en"').original_language.value_counts()

# %%
filmes_sem_lingua_original_em_ingles = tmdb.query('original_language != "en"')
sns.catplot(x='original_language', kind='count', data=filmes_sem_lingua_original_em_ingles, 
            aspect=2, 
            palette='Oranges_r',
            order=total_por_lingua_de_outros_filmes.index)

# %% [markdown]
# # Revisando o papel da media, mediana, medidas de tendencia central, dispersão, desvio padrão, box-plot, histograma

# %%
notas_do_toy_story = notas.query('filmeId==1')
notas_do_jumanji = notas.query('filmeId==2')
print(len(notas_do_toy_story), len(notas_do_jumanji))
# Out:
# 215 110

# %%
print(f'Nota média do Toy Story {notas_do_toy_story.nota.mean():.2f}')
print(f'Nota média do Jumanji {notas_do_jumanji.nota.mean():.2f}')
# Out:
# Nota média do Toy Story 3.92
# Nota média do Jumanji 3.43

# %%
print("Mediana do Toy Story %.2f" % notas_do_toy_story.nota.median())
print("Mediana do Jumanji %.2f" % notas_do_jumanji.nota.median())
# Out:
# Mediana do Toy Story 4.00
# Mediana do Jumanji 3.50

# %%
plt.boxplot([notas_do_toy_story.nota, notas_do_jumanji.nota])
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# {'boxes': [<matplotlib.lines.Line2D at 0x7f7a6004afd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f7a5ffe91d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7a60003310>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f7a60003cd0>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f7a6004af90>,
# ...
#   <matplotlib.lines.Line2D at 0x7f7a60048b50>]}

# %%
sns.boxplot(x = "filmeId", y = "nota", data = notas.query("filmeId in (1,2)"))

# %%
sns.boxplot(x = "filmeId", y = "nota", data = notas.query("filmeId in (1,2,3,4,5)"))

# %%
print(f'Desvio padrão do Jumanji {notas_do_jumanji.nota.std():.2f}', 
      f'\nDesvio padrão do Toy Story {notas_do_toy_story.nota.std():.2f}')
# Out:
# Desvio padrão do Jumanji 0.88
# Desvio padrão do Toy Story 0.83

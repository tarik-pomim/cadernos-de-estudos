# %% [markdown]
# ## **Logica de programação com Python**

# %%
1+1
# Out:
# 2

# %%
"Tarik"
# Out:
# 'Tarik'

# %%
'Tarik'
# Out:
# 'Tarik'

# %%
nome = 'Tarik'

# %%
nome
# Out:
# 'Tarik'

# %%
idade = 37

# %%
idade
# Out:
# 37

# %%
print(f'O nome é {nome} e sua idade é {idade} anos.')
# Out:
# O nome é Tarik e sua idade é 37 anos.

# %%
idade = 38

# %%
print(f'O nome é {nome} e sua idade é {idade} anos.')
# Out:
# O nome é Tarik e sua idade é 38 anos.

# %% [markdown]
# # **Criando minha primeira função**

# %%
def saudacao():
  nome = input('Qual o seu nome? ')
  print(f'Olá, {nome}')

# %%
saudacao()
# Out:
# Qual o seu nome? Tarik
# Olá, Tarik

# %% [markdown]
# # **Parametros**

# %%
nome = 'Tarik'

# %%
def saudacao_com_parametro(nome_da_pessoa):
  print(f'Olá, {nome_da_pessoa}')

# %%
saudacao_com_parametro(nome)
# Out:
# Olá, Tarik

# %% [markdown]
# # **Condicional**

# %%
idade = 15
def verifica_se_pode_dirigir(idade):
  if idade >= 18:
    print('Tem permissão para dirigir.')
  else:
    print('Não tem permissão para dirigir.')

verifica_se_pode_dirigir(idade)
# Out:
# Não tem permissão para dirigir.

# %% [markdown]
# # **Convertendo tipo para inteiro**

# %%
def verifica_se_pode_dirigir_sem_parametro():
  idade = input('Qual sua idade? ')
  idade = int(idade)
  if idade >= 18:
    print('Tem permissão para dirigir.')
  else:
    print('Nao tem permissão para dirigir.')

verifica_se_pode_dirigir_sem_parametro()
# Out:
# Qual sua idade? 20
# Tem permissão para dirigir.

# %% [markdown]
# # **Lista**

# %%
idade = 22
idade
# Out:
# 22

# %%
type(idade)
# Out:
# int

# %%
nome = 'Tarik'

# %%
type(nome)
# Out:
# str

# %%
idades = [18, 22, 15, 50]
type(idades)
# Out:
# list

# %%
idades[2]
# Out:
# 15

# %%
idades = [18, 22, 15, 50]
#         0   1    2   2    python começa no indice zero 0
#        -4  -3   -2  -1

# %%
idades[1]
# Out:
# 22

# %%
idades[0:2]
# Out:
# [18, 22]

# %%
idades[1:]
# Out:
# [22, 15, 50]

# %%
idades[-1]
# Out:
# 50

# %%
idades[-4]
# Out:
# 18

# %% [markdown]
# # **Laços e loops**

# %%
idades
# Out:
# [18, 22, 15, 50]

# %%
# for fora da função

def verifica_se_pode_dirigir(idade):
  if idade >= 18:
    print(f'{idade} anos de idade, TEM permissão para dirigir.')
  else:
    print(f'{idade} anos de idade, NAO TEM tem permissão para dirigir.')

for idade in idades:
  verifica_se_pode_dirigir(idade)
# Out:
# 18 anos de idade, TEM permissão para dirigir.
# 22 anos de idade, TEM permissão para dirigir.
# 15 anos de idade, NAO TEM tem permissão para dirigir.
# 50 anos de idade, TEM permissão para dirigir.

# %%
# for dentro da função

def verifica_se_pode_dirigir(idades):
  for idade in idades:
    if idade >= 18:
      print(f'{idade} anos de idade, TEM permissão para dirigir.')
    else:
      print(f'{idade} anos de idade, NAO TEM tem permissão para dirigir.')

verifica_se_pode_dirigir(idades)
# Out:
# 18 anos de idade, TEM permissão para dirigir.
# 22 anos de idade, TEM permissão para dirigir.
# 15 anos de idade, NAO TEM tem permissão para dirigir.
# 50 anos de idade, TEM permissão para dirigir.

# %% [markdown]
# # **Booleano**

# %%
idade = 18
idade >= 18
# Out:
# True

# %%
idade = 15
idade >= 18
# Out:
# False

# %%
permissoes = []
idades = [20, 14, 40]

def verifica_se_pode_dirigir(idades, permissoes):
  for idade in idades:
    if idade >= 18:
      permissoes.append(True)
    else:
      permissoes.append(False)

verifica_se_pode_dirigir(idades, permissoes)

# %%
permissoes
# Out:
# [True, False, True]

# %%
for permissao in permissoes:
  if permissao:
    print('Tem permissao para dirigir.')
  else:
    print('Não tem permissão para dirigir.')
# Out:
# Tem permissao para dirigir.
# Não tem permissão para dirigir.
# Tem permissao para dirigir.

# %% [markdown]
# # **Tipos em uma lista**

# %%
lista = ['Tarik', 37, True, '18']

for elemento in lista:
  print(f'O elemento {elemento} é do tipo: ', type(elemento))
# Out:
# O elemento Tarik é do tipo:  <class 'str'>
# O elemento 37 é do tipo:  <class 'int'>
# O elemento True é do tipo:  <class 'bool'>
# O elemento 18 é do tipo:  <class 'str'>

# %% [markdown]
# # **Import**

# %%
from random import randrange, seed

# %%
seed(11)  # é uma semente inicial para gerações postumas de numeros aleatorios

# %%
randrange(0, 11)
# Out:
# 7

# %%
notas_matematica = []

for notas in range(8):
  notas_matematica.append(randrange(0, 11))
  
notas_matematica
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]

# %%
len(notas_matematica)
# Out:
# 8

# %% [markdown]
# # **Matplotlib**

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(1, 9))
y = notas_matematica
plt.plot(x, y, marker='o')
plt.title('Notas de matematica')
plt.xlabel('Provas')
plt.ylabel('Notas')
plt.show()

# %%
notas_matematica
# Out:
# [8, 7, 7, 8, 9, 3, 2, 8]

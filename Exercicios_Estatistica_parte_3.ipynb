# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##Pesando embalagens

# %% [markdown]
# Um fabricante de farinha afirma que a quantidade média de farinha nas embalagens de seu principal produto é de 500 g. Um teste de pesagem em 30 embalagens amostradas ao acaso mostrou um peso médio igual à 485 g. Estudos anteriores afirmam que a distribuição dos pesos segue uma normal e que o desvio padrão populacional é igual a 20 g. Considerando um nível de significância igual a 5%, responda as seguintes questões:

# %% [markdown]
# 1) Qual a hipótese nula a ser testada?
# Hipotese nula pois o fabricante afirma que a media=500. Quando é igualdade é hipotese nula.
#
# 2) Qual o valor da estatística de teste?
# -4.107919181288746
#
# 3) Qual a conclusão do teste?
# Como a media amostral x_barra é significativamente menor que 500g, rejeitamos H0.

# %%
# informações enunciado
media_populacional_mi_zero = 500
media_amostral_x_barra = 485
desvio_padrao_pop_sigma = 20

# %%
significancia = 0.05
confianca = 1 - significancia
n = 30

# %%
probabilidade = (0.5 + (confianca)/2)
probabilidade
# Out:
# 0.975

# %%
# onbtendo z_alpha_2 (area de aceitação)
from scipy.stats import norm

z_alpha_2 = norm.ppf(probabilidade)
z_alpha_2
# Out:
# 1.959963984540054

# %%
# obtendo estatistica-teste z
z = (media_amostral_x_barra - media_populacional_mi_zero) / (desvio_padrao_pop_sigma / np.sqrt(n))
z
# Out:
# -4.107919181288746

# %%
# teste bicaudal: rejeitar H0 se z <= -z_alpha2 ou se z >= z_alpha_2
# quando temos uma resposta True, significa que precisamos rejeitar a hipótese nula.

if (z <= -z_alpha_2) or (z >= z_alpha_2):
  print('Hipotese numa rejeitada.')
else:
  print('Hipotese nula aceita.')
# Out:
# Hipotese numa rejeitada.

# %% [markdown]
# Como a media amostral x_barra é significativamente menor que 500g, rejeitamos H0.
#
# ### <font color='green'>Conclusão: Como a média amostral $\bar{x}$ é significativamente menor que 500g, rejeitamos $H_0$. Neste caso, devem ser tomadas providências para ajustar o maquinário que preenche as embalagens.</font>

# %% [markdown]
# ##Calculando o p-valor

# %% [markdown]
# Considere novamente os dados do exercício anterior. Um fabricante de farinha afirma que a quantidade média de farinha nas embalagens de seu principal produto é de 500 g. Um teste de pesagem em 30 embalagens amostradas ao acaso mostrou um peso médio igual à 485 g. Estudos anteriores afirmam que a distribuição dos pesos segue uma normal e que o desvio padrão populacional é igual a 20 g. Com um nível de significância igual a 5%, teste a hipótese nula de que a média do processo é igual a 500 g e marque a alternativa que indica o p-valor do teste aplicado (considere somente 5 casas decimais).

# %% [markdown]
# Duas formas:

# %%
p_valor = 2 * (1 - norm.cdf(abs(z))) 
p_valor
# Out:
# 3.992397476904053e-05

# %%
p_valor = 2 * norm.sf(abs(z))
p_valor
# Out:
# 3.992397476901338e-05

# %% [markdown]
# ## Tratamento de esgoto

# %% [markdown]
# A empresa Limpa Esgoto garante ser capaz de realizar o tratamento de esgoto e obter, no máximo, 150 g de impurezas para cada mil litros de esgoto tratado. Vinte amostras de mil litros de esgoto apresentaram, em média, 230 g de impurezas e desvio padrão amostral igual a 90 g.

# %% [markdown]
# Assumindo alfa igual a 5% e população normalmente distribuída, seria possível discordar da empresa Limpa Esgoto? Assinale a alternativa que apresenta a estatística de teste e a decisão correta do teste.

# %%
media_amostral_x_barra = 230  # g de impurezas
desvio_padrao_amostral_s = 90
media = 150
significancia = 0.05
confianca = 1 - significancia
n = 20
grau_de_liberdade = n - 1

# %%
from scipy.stats import t as t_student

# %%
t_alpha = t_student.ppf(confianca, grau_de_liberdade)
t_alpha
# Out:
# 1.729132811521367

# %%
t = (media_amostral_x_barra - media) / (desvio_padrao_amostral_s / np.sqrt(n))
t
# Out:
# 3.9752319599996264

# %%
t >= t_alpha
# Out:
# True

# %%
# Codigo da resposta

from scipy.stats import t as t_student
import numpy as np

media_amostra = 230
desvio_padrao_amostra = 90
media = 150
significancia = 0.05
confianca = 1 - significancia
n = 20
graus_de_liberdade = n - 1

t_alpha = t_student.ppf(confianca, graus_de_liberdade)

t = (media_amostra - media) / (desvio_padrao_amostra / np.sqrt(n))

print('t(alpha) =', round(t_alpha, 4))
print('t =', round(t, 4))
if(t >= t_alpha):
    print('Rejeitar H0')
else:
    print('Aceitar H0')
# Out:
# t(alpha) = 1.7291
# t = 3.9752
# Rejeitar H0

# %% [markdown]
# ## Falta queijo na pizza?

# %% [markdown]
# A pizzaria Muito Queijo alega que a quantidade de queijo em suas pizzas tamanho família é de, no mínimo, 350 g. Uma amostra de 35 pizzas tamanho família revelou uma média de 330 g de queijo por pizza. O desvio padrão amostral foi de 80 g.

# %% [markdown]
# Assumindo alfa igual a 5% e população normalmente distribuída, seria possível discordar da alegação da pizzaria? Assinale a alternativa que apresenta a estatística de teste e a decisão correta do teste.

# %%
media_amostral_x_barra = 330  # g de impurezas
desvio_padrao_amostral_s = 80
media = 350
significancia = 0.05
confianca = 1 - significancia
n = 35
grau_de_liberdade = n - 1

# %%
probabilidade = (0.5 + (confianca)/2)
probabilidade
# Out:
# 0.975

# %%
z_alpha = norm.ppf(probabilidade)
z_alpha
# Out:
# 1.959963984540054

# %%
z = (media_amostral_x_barra - media) / (desvio_padrao_amostral_s / np.sqrt(n))
z
# Out:
# -1.479019945774904

# %%
if z <= -z_alpha:
  print('rejeitar h0')
else:
  print('aceitar h0')
# Out:
# aceitar h0

# %% [markdown]
# Ao nível de confiança de 95%, não podemos rejeitar a hipótese de que as pizzas da pizzaria Muito Queijo têm pelo menos 350 g de queijo.

# %%
# codigo da resposta:

from scipy.stats import norm
import numpy as np

media_amostra = 330
desvio_padrao_amostra = 80
media = 350
significancia = 0.05
confianca = 1 - significancia
n = 35

z_alpha = norm.ppf(confianca)

z = (media_amostra - media) / (desvio_padrao_amostra / np.sqrt(n))

print('z(alpha) =', round(z_alpha, 3))
print('z =', round(z, 3))
if(z <= -z_alpha):
    print('Rejeitar H0')
else:
    print('Aceitar H0')
# Out:
# z(alpha) = 1.645
# z = -1.479
# Aceitar H0

# %% [markdown]
# ##Testando uma nova linha de shampoos

# %% [markdown]
# Um fabricante de cosméticos afirma que a adição de um novo composto químico em sua linha de shampoos consegue promover em mais de 2 centímetros o crescimento dos fios de cabelo em um período de 60 dias. Duas amostras de pessoas foram selecionadas e testadas, uma utilizando o shampoo novo (com o composto) e a outra com o shampoo antigo (sem o composto).

# %% [markdown]
# Os resultados (crescimento dos fios de cabelo em centímetros) podem ser verificados na tabela abaixo:

# %%
shampoo_Novo = pd.Series([3.4, 4.9, 2.8, 5.5, 3.7, 2.5, 4.3, 4.6, 3.7, 3.4])
shampoo_Antigo = pd.Series([0.3, 1.2, 1.2, 1.7, 1.1, 0.6, 1.2, 1.5, 0.5, 0.7])

# %% [markdown]
# Assumindo um nível de confiança de 95% e considerando que as populações se distribuem como uma normal, podemos acreditar na afirmação do fabricante do shampoo? Assinale a alternativa que apresenta a estatística de teste e a decisão correta do teste.

# %% [markdown]
# ### Um pouco mais de teoria:

# %% [markdown]
# como se trata de um problema um pouco diferente do apresentado em nossa aula, vamos esclarecer alguns pontos para ajudar na solução:

# %% [markdown]
# 1) Em testes entre duas amostras, quando realizamos a escolha da distribuição amostral adequada (passo 2) e perguntamos se n ≥ 30, temos que considerar que n = n1 + n2, onde n1 é o tamanho da primeira amostra e n2 o tamanho da segunda;

# %% [markdown]
# 2) Quando n1 + n2 ≥ 30, utilizamos z (normal), e quando n1 + n2 < 30, σ não for conhecido e as populações forem normalmente distribuídas, utilizamos t (t-Student);

# %% [markdown]
# 3) Quando utilizamos a tabela t de Student, em teste de duas amostras, os graus de liberdade são obtidos da seguinte forma: n1 + n2 - 2;

# %% [markdown]
# 4) Quando o problema nos pergunta se podemos acreditar na afirmação do fabricante, está nos indicando o que devemos testar, ou seja, a nossa hipótese alternativa (H1), que no caso é:

# %% [markdown]
# H1: μ1 - μ2 > 2

# %% [markdown]
# Onde:
#
# μ1 = Crescimento médio dos cabelos com o uso do novo shampoo
#
# μ2 = Crescimento médio dos cabelos com o uso do shampoo antigo.

# %% [markdown]
# 5) Em nosso próximo vídeo, utilizaremos o ztest_ind() do statsmodels para solucionar problemas como este. Um teste similar ao ztest_ind(), que utiliza a distribuição t de Student, é o ttest_ind(). Observe que o ttest_ind() retorna a estatística de teste, o p-valor e também os graus de liberdade.

# %%
# selecao das amostras:
print(shampoo_Novo)
print(shampoo_Antigo)
# Out:
# 0    3.4
# 1    4.9
# 2    2.8
# 3    5.5
# 4    3.7
# 5    2.5
# 6    4.3
# 7    4.6
# 8    3.7
# 9    3.4
# dtype: float64
# 0    0.3
# 1    1.2
# 2    1.2
# 3    1.7
# 4    1.1
# 5    0.6
# 6    1.2
# 7    1.5
# 8    0.5
# 9    0.7
# dtype: float64

# %%
# dados do problema:
media_amostra_novo_xbarra = shampoo_Novo.mean()
media_amostra_antigo_xbarra = shampoo_Antigo.mean()
desvio_padrao_amostra_novo_S = shampoo_Novo.std()
desvio_padrao_amostra_antigo_S = shampoo_Antigo.std()

# %%
print(media_amostra_novo_xbarra - media_amostra_antigo_xbarra)
# Out:
# 2.88

# %%
significancia = 0.05  # confiança 95%
confianca = 1 - significancia
n_novo = 10
n_antigo = 10
D_0 = 2
graus_de_liberdade = 10 + 10 - 2

# %%
# Testaremos a hipotese alternativa:
# H1: μ1 - μ2 > 2

# %%
t_alpha = t_student.ppf(confianca, graus_de_liberdade)
t_alpha.round(2)
# Out:
# 1.73

# %%
numerador = (media_amostra_novo_xbarra - media_amostra_antigo_xbarra) - D_0
denominador = np.sqrt((desvio_padrao_amostra_novo_S ** 2 / n_novo) + (desvio_padrao_amostra_antigo_S ** 2 / n_antigo))
t = numerador / denominador
t.round(2)
# Out:
# 2.66

# %%
if(t >= t_alpha):
    print('Rejeitar H0')
else:
    print('Aceitar H0')
# Out:
# Rejeitar H0

# %%
# Usando statsmodels:

from statsmodels.stats.weightstats import DescrStatsW

shampoo_Novo = pd.Series([3.4, 4.9, 2.8, 5.5, 3.7, 2.5, 4.3, 4.6, 3.7, 3.4])
shampoo_Antigo = pd.Series([0.3, 1.2, 1.2, 1.7, 1.1, 0.6, 1.2, 1.5, 0.5, 0.7])

significancia = 0.05

test_A = DescrStatsW(shampoo_Novo)
test_B = DescrStatsW(shampoo_Antigo)
test = test_A.get_compare(test_B)

t, p_valor, df = test.ttest_ind(alternative='larger', value=2)

print('t =', round(t, 4))
print('p-valor =', round(p_valor, 4))
print('graus de liberdade =', df)

if(p_valor <= significancia):
    print('Rejeitar H0')
else:
    print('Aceitar H0')
print('')
# Out:
# t = 2.6646
# p-valor = 0.0079
# graus de liberdade = 18.0
# Rejeitar H0

# %% [markdown]
# ## A importância dos cursos da Alura

# %% [markdown]
# Desconfiado da eficiência dos cursos e materiais de estudo online da Alura, um professor resolveu realizar um teste com um grupo de 14 alunos de sua classe. Para isto, ele submeteu estes alunos a duas etapas distintas e logo depois de cada etapa, aplicou uma avaliação. Na etapa inicial, foram oferecidas aulas normais, sem a utilização do material de apoio da Alura. Na segunda etapa, foram também oferecidas aulas normais, mas com a utilização do material de apoio da Alura. As notas obtidas pelos alunos estão na tabela abaixo:

# %%
import pandas as pd
import string

dados = {'Sem Alura': [7, 8, 6, 6, 10, 4, 2, 5, 9, 2, 4, 9, 1, 10],
         'Com Alura': [10, 10, 9, 9, 9, 7, 5, 8, 10, 6, 3, 7, 4, 8]}

letras = list(string.ascii_uppercase[:len(dados['Sem Alura'])])

index = ['Aluno ' + letra for letra in letras]
df = pd.DataFrame(data = dados, index = index)
df
# Out:
#          Sem Alura  Com Alura
# Aluno A          7         10
# Aluno B          8         10
# Aluno C          6          9
# Aluno D          6          9
# Aluno E         10          9
# Aluno F          4          7
# Aluno G          2          5
# Aluno H          5          8
# Aluno I          9         10
# Aluno J          2          6
# Aluno K          4          3
# Aluno L          9          7
# Aluno M          1          4
# Aluno N         10          8

# %% [markdown]
# Assinale a alternativa que apresenta o resultado do teste, não paramétrico de Wilcoxon, aplicado pelo professor (estatística de teste T e decisão do teste). Considere um nível de significância de 10%.

# %%
from scipy.stats import wilcoxon

# %%
T, p_valor = wilcoxon(df['Sem Alura'], df['Com Alura'])
print(T)
print(p_valor)
# Out:
# 14.0
# 0.01405249884356315

# %%
# codigo da resposta:

from scipy.stats import wilcoxon

sem_Alura = pd.Series([ 7,  8, 6, 6, 10, 4, 2, 5,  9, 2, 4, 9, 1, 10])
com_Alura = pd.Series([10, 10, 9, 9,  9, 7, 5, 8, 10, 6, 3, 7, 4,  8])

significancia = 0.10

T, p_valor = wilcoxon(sem_Alura, com_Alura)
print('T =', T)

if(p_valor <= significancia):
    print('Rejeitar H0')
else:
    print('Aceitar H0')
# Out:
# T = 14.0
# Rejeitar H0

# %% [markdown]
# Rejeitamos H0, pois existe uma diferença significativa na nota média do grupo após a utilização do material de apoio.

# %% [markdown]
# ## Testando teorias

# %% [markdown]
# Um professor acredita que alunos que praticam exercícios físicos têm uma performance média escolar superior àquela obtida por alunos que não praticam. Para provar sua teoria, selecionou duas amostras aleatórias, uma com 9 alunos que não praticam exercícios físicos e outra com 10 alunos que cultivam o hábito de se exercitar. A tabela abaixo mostra as notas dos alunos no último ano:

# %%
sem_exercicios = [7, 6, 7, 8, 6, 8, 6, 9, 5]
com_exercicios = [8, 7, 6, 6, 8, 6, 10, 6, 7, 8]

# %% [markdown]
# Teste a hipótese da média das notas dos alunos que praticam exercícios ser maior que a média das notas dos alunos que não praticam. Assinale a alternativa que apresenta o resultado do teste (estatística de teste u e decisão do teste). Considere um nível de significância de 10%.

# %%
from scipy.stats import mannwhitneyu

# %%
significancia = 0.1
confianca = 1 - significancia
n_1 = len(sem_exercicios)
n_2 = len(com_exercicios)
graus_de_liberdade = n_1 + n_2 - 2

# %%
t_alpha = t_student.ppf(confianca, graus_de_liberdade)  # confianca para (+), significancia para (-)
t_alpha.round(2)
# Out:
# 1.33

# %%
u, p_valor = mannwhitneyu(com_exercicios, sem_exercicios, alternative='greater')
# hipotese que esta sendo testada: 'com' tem nota 'greater' que 'sem'. A ordem dos args depende da hipotese.
print(u)
print(p_valor)
# Out:
# 50.0
# 0.35118642828565927

# %%
u > t_alpha
# Out:
# True

# %%
p_valor <= significancia
# Out:
# False

# %%
# codigo da resposta:

from scipy.stats import mannwhitneyu

sem_Exercicios = pd.Series([7, 6, 7, 8, 6, 8, 6, 9, 5])
com_Exercicios = pd.Series([8, 7, 6, 6, 8, 6, 10, 6, 7, 8])

significancia = 0.10

u, p_valor = mannwhitneyu(com_Exercicios, sem_Exercicios, alternative='greater')

print('u =', u)

if(p_valor <= significancia):
    print('Rejeitar H0')
else:
    print('Aceitar H0')
# Out:
# u = 50.0
# Aceitar H0

# %% [markdown]
# Aceitar H0, ou seja, não podemos afirmar que a performance escolar de alunos que praticam exercicios fisicos é superior a de alunos que não praticam exercicios fisicos.

# %% [markdown]
# # 7daysOfCode ALURA

# %% [markdown]
# # Dia1 - Data Cleaning and Preparation

# %% [markdown]
# Olá, Tarik Pomim.
#
# Chegou o grande momento!
#
# Você vai passar os próximos 7 dias praticando Dados comigo.
#
# Antes de começar, me responda uma pergunta: com o que você acha que Data Scientists gastam mais tempo durante seu trabalho?
#
# Eu queria poder mentir pra você e dizer que passamos a maior parte do nosso tempo criando modelos altamente complexos e brincando com o que há de mais avançado tecnologicamente.
#
# Eu queria, ainda, poder dizer que as bases de dados que você irá trabalhar já estão limpas, bem processadas e prontas para que você possa criar visualizações e análises poderosas.
#
# Mas, na verdade, não é bem isso. O que passamos a maior parte do tempo fazendo é a preparação do dado, mais especificamente nas partes de limpeza e transformação.
#
# Em uma pesquisa com cerca de 80 cientistas de dados, as etapas de preparação de dados foram responsáveis por consumir mais de 80% do tempo deles, reforçando a necessidade de desenvolver a habilidade de tratar dados e deixá-los prontos para a parte mais divertida: criar modelos e análises.
#
# Por isso, quero te dar um ótimo desafio para desenvolver e aprimorar essa skill tão importante para toda pessoa cientista de dados.
#
# Neste primeiro dia, [eu te proponho baixar um dataset do portal do CEAPS](https://www12.senado.leg.br/transparencia/dados-abertos-transparencia/dados-abertos-ceaps) (Cota para Exercício da Atividade Parlamentar dos Senadores) e aplicar processos de tratamento e limpeza de dados nele (processo conhecido como Data Wrangling).
#
# Basicamente, o CEAPS contém todos os gastos que senadores brasileiros declararam, divididos por ano.
#
# Esse tipo de dado é tão importante que já criou várias iniciativas interessantes, como a [Operação Serenata de Amor](https://serenata.ai/), que aplica Inteligência Artificial para analisar gastos de deputados brasileiros, e que já foi capaz de identificar vários usos indevidos do dinheiro público.
#
# Imagina as coisas que você pode criar!
#
# Os dados do CEAPS contêm uma série de problemas que podem dificultar a criação de análises mais aprofundadas.
#
# Uma das primeiras coisas que você pode fazer é identificar tais inconsistências, como campos que possuem valores nulos ou duplicados, converter campos de data que estão sendo carregados como texto, corrigir valores monetários, nomes incorretos, formatar campos de CNPJ, etc.

# %% [markdown]
# ## Dica

# %% [markdown]
# Os dados do CEAPS estão divididos por ano.
#
# Que tal juntar dados de vários anos em um grande dataset e aplicar técnicas de limpeza e processamento dos dados?
#
# Você poderia pegar dados dos últimos quatro anos e aplicar o que usou nesse exercício.
#
# Além disso, também proponho que você documente o seu processo de tratamento dos dados (pode ser no próprio Jupyter Notebook). Assim, qualquer pessoa que consumir o seu trabalho saberá qual foi sua intuição e as técnicas utilizadas, além de facilitar a reprodutibilidade.
#
# Tire o maior proveito possível dos comentários no código!
#
# Não existe uma receita de bolo para quais técnicas utilizar na limpeza de dados, isso varia de projeto para projeto. Contudo, existem algumas coisas que você pode fazer inicialmente.
#
# Lidar com dados nulos (deletar ou imputar um valor novo, por exemplo); remover colunas que não trazem nenhuma informação; processar datas que estão em formato incorreto; alterar o tipo da coluna (uma coluna que é numérica está como texto no Pandas); remover duplicados; dentre outras.
#
# [Esse post da Tableau](https://www.tableau.com/learn/articles/what-is-data-cleaning) traz algumas dicas sobre técnicas que você pode utilizar.

# %% [markdown]
# ## Extra

# %% [markdown]
# O [Portal da Transparência](https://www.portaltransparencia.gov.br/) é um ótimo site para encontrar novos datasets para explorar e criar projetos. Esse é o site que contém informações detalhadas sobre a execução orçamentária e financeira da União.
#
# Devido a cada sistema ter sua forma de exportação dos dados, é possível identificar uma série de oportunidades de melhora nos dados exportados. Que tal expandir o seu trabalho explorando outros datasets?
#
# Ou, ainda: e se você hospedar esse seu dataset limpo em uma plataforma que outras pessoas possam utilizar?
#
# Existem várias plataformas legais para isso, desde o Kaggle, onde você pode submeter datasets para a comunidade, até iniciativas brasileiras de dados abertos, como o Brasil IO.

# %% [markdown]
# # Importações

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Datasets

# %% [markdown]
# Apontando URIs:

# %%
uri_2019 = 'https://www.senado.gov.br/transparencia/LAI/verba/despesa_ceaps_2019.csv'
uri_2020 = 'https://www.senado.gov.br/transparencia/LAI/verba/despesa_ceaps_2020.csv'
uri_2021 = 'https://www.senado.gov.br/transparencia/LAI/verba/despesa_ceaps_2021.csv'
uri_2022 = 'https://www.senado.gov.br/transparencia/LAI/verba/despesa_ceaps_2022.csv'

# %% [markdown]
# Lendo CSVs com parametros para melhor adequação:

# %%
dados_2019 = pd.read_csv(uri_2019, encoding='latin-1', sep = ';', skiprows=1, decimal=',')
dados_2020 = pd.read_csv(uri_2020, encoding='latin-1', sep = ';', skiprows=1, decimal=',')
dados_2021 = pd.read_csv(uri_2021, encoding='latin-1', sep = ';', skiprows=1, decimal=',')
dados_2022 = pd.read_csv(uri_2022, encoding='latin-1', sep = ';', skiprows=1, decimal=',')

# %% [markdown]
# Exemplos dos datasets:

# %%
dados_2019.sample(3)
# Out:
#         ANO  MES             SENADOR  \
# 21142  2019    3    ZEQUINHA MARINHO
# 1296   2019    9  AROLDE DE OLIVEIRA
# 16832  2019    9     RODRIGO PACHECO
#
#                                             TIPO_DESPESA            CNPJ_CPF  \
# 21142  Locomoção, hospedagem, alimentação, combustíve...  83.324.921/0001-37
# 1296   Aluguel de imóveis para escritório político, c...  33.345.232/0001-30
# 16832                Divulgação da atividade parlamentar  01.768.201/0001-04
#
#                                     FORNECEDOR     DOCUMENTO        DATA  \
# 21142                    SUPER POSTO 2000 LTDA     000271110  28/03/2019
# 1296   PALMARES ADMINISTRADORA DE IMÓVEIS LTDA  19.167.191-6  10/09/2019
# 16832       Empresa Jornalistica nova Imprensa  201900000277  01/10/2019
#
#       DETALHAMENTO  VALOR_REEMBOLSADO  COD_DOCUMENTO
# 21142          NaN              126.0        2118526
# 1296           NaN             1698.1        2131293
# 16832          NaN              800.0        2132768

# %%
dados_2020.sample(3)
# Out:
#        ANO  MES         SENADOR  \
# 6923  2020    6  LASIER MARTINS
# 8973  2020    6  MARCOS ROGÉRIO
# 2931  2020    5   EDUARDO GOMES
#
#                                            TIPO_DESPESA            CNPJ_CPF  \
# 6923  Aquisição de material de consumo para uso no e...  00.758.665/0001-69
# 8973  Passagens aéreas, aquáticas e terrestres nacio...  09.296.295/0001-60
# 2931  Locomoção, hospedagem, alimentação, combustíve...  00.306.597/0096-68
#
#                                    FORNECEDOR DOCUMENTO        DATA  \
# 6923        Birô de Informática Nacional Ltda     12821  03/06/2020
# 8973                                     AZUL    FI7QHQ  15/06/2020
# 2931  Cascol Combustíveis para Veículos Ltda.    745224  21/05/2020
#
#                                            DETALHAMENTO  VALOR_REEMBOLSADO  \
# 6923                  Locação de móveis e equipamentos.            1500.00
# 8973  Companhia Aérea: AZUL, Localizador: FI7QHQ. Pa...             740.47
# 2931  DESPESA COM COMBUSTÍVEL QUE SERVE O SENADOR ED...             160.00
#
#       COD_DOCUMENTO
# 6923        2145769
# 8973        2146048
# 2931        2144942

# %%
dados_2021.sample(3)
# Out:
#        ANO  MES             SENADOR  \
# 9968  2021    6        MAILZA GOMES
# 3707  2021   11       EDUARDO GOMES
# 9766  2021   12  LUIS CARLOS HEINZE
#
#                                            TIPO_DESPESA            CNPJ_CPF  \
# 9968  Locomoção, hospedagem, alimentação, combustíve...  10.172.179/0001-18
# 3707  Locomoção, hospedagem, alimentação, combustíve...  00.692.418/0006-11
# 9766  Locomoção, hospedagem, alimentação, combustíve...  97.168.124/0002-01
#
#                            FORNECEDOR  DOCUMENTO        DATA  \
# 9968                         SS SOUSA  000001022  23/06/2021
# 3707  AUTO POSTO CINCO ESTRELAS LTDA.  000081655  26/11/2021
# 9766            IRMAOS BASSOTTO  LTDA     107172  19/12/2021
#
#                                            DETALHAMENTO  VALOR_REEMBOLSADO  \
# 9968                                                NaN             610.00
# 3707  DESPESA COM COMBUSTÍVEL QUE SERVE O SENADOR ED...             211.48
# 9766                                                NaN             200.00
#
#       COD_DOCUMENTO
# 9968        2163180
# 3707        2171414
# 9766        2178716

# %%
dados_2022.sample(3)
# Out:
#        ANO  MES             SENADOR  \
# 6490  2022    4  LUIS CARLOS HEINZE
# 6813  2022    2       MARA GABRILLI
# 9024  2022    7             ROMÁRIO
#
#                                            TIPO_DESPESA            CNPJ_CPF  \
# 6490  Locomoção, hospedagem, alimentação, combustíve...  11.174.560/0001-89
# 6813  Locomoção, hospedagem, alimentação, combustíve...  09.640.162/0001-69
# 9024  Passagens aéreas, aquáticas e terrestres nacio...  16.978.175/0001-08
#
#                                              FORNECEDOR DOCUMENTO        DATA  \
# 6490  Glaicon Fonatana Piovesan - Hotel Parque das T...    018632  09/04/2022
# 6813            CENTRO AUTOMOTIVO ALAMEDA CAMPINAS LTDA       022  04/03/2022
# 9024                    Adria Viagens e Turismo LTDA ME    FWPTHD  21/07/2022
#
#                                            DETALHAMENTO  VALOR_REEMBOLSADO  \
# 6490                                                NaN             321.60
# 6813  Aquisição de combustível para veículos utiliza...             474.39
# 9024  Companhia Aérea: LATAM, Localizador: FWPTHD. P...            2024.24
#
#       COD_DOCUMENTO
# 6490        2178095
# 6813        2176645
# 9024        2184402

# %% [markdown]
# Concatenando datasets em um único dataset:

# %%
dataset = pd.concat([dados_2019, dados_2020, dados_2021, dados_2022])

# %%
dataset.head(5)
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2019    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2019    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 2  2019    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 3  2019    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 4  2019    2  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
#
#              CNPJ_CPF                     FORNECEDOR  DOCUMENTO        DATA  \
# 0  05.914.650/0001-66                       ENERGISA  006582758  04/01/2019
# 1  05.914.650/0001-66                       ENERGISA  006582755  04/01/2019
# 2      004.948.028-63  GILBERTO PISELO DO NASCIMENTO      00119  07/01/2019
# 3  05.423.963/0001-11                  OI MÓVEL S.A.   86161151  25/12/2018
# 4  05.914.650/0001-66                       ENERGISA  007236036  04/02/2019
#
#                                         DETALHAMENTO  VALOR_REEMBOLSADO  \
# 0  Despesa com pagamento de energia elétrica do e...              66.02
# 1  Despesa com pagamento de energia elétrica do e...             139.98
# 2  Despesa com pagamento de aluguel de imóvel par...            6000.00
# 3  Despesa com pagamento de telefonia para o escr...             316.39
# 4  Despesa com pagamento de energia elétrica para...              99.45
#
#    COD_DOCUMENTO
# 0        2116543
# 1        2116546
# 2        2113817
# 3        2116541
# 4        2116550

# %%
dataset.tail(5)
# Out:
#         ANO  MES           SENADOR  \
# 10643  2022    7  ZEQUINHA MARINHO
# 10644  2022    7  ZEQUINHA MARINHO
# 10645  2022    8  ZEQUINHA MARINHO
# 10646  2022    8  ZEQUINHA MARINHO
# 10647  2022    8  ZEQUINHA MARINHO
#
#                                             TIPO_DESPESA            CNPJ_CPF  \
# 10643  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 10644  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 10645  Locomoção, hospedagem, alimentação, combustíve...  27.522.923/0001-60
# 10646  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 10647  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
#
#                                   FORNECEDOR  DOCUMENTO        DATA  \
# 10643                          Exceller Tour     FRMXSO  26/07/2022
# 10644                          Exceller Tour     YQRYAW  26/07/2022
# 10645  Casarao da Vila Restaurante LTDA - ME  000127032  03/08/2022
# 10646                          Exceller Tour     FLXNAO  02/08/2022
# 10647                          Exceller Tour     TKR98A  07/08/2022
#
#                                             DETALHAMENTO  VALOR_REEMBOLSADO  \
# 10643  Companhia Aérea: GOL, Localizador: FRMXSO. Pas...            1826.25
# 10644  Companhia Aérea: LATAM, Localizador: YQRYAW. P...            2189.41
# 10645                                                NaN              26.57
# 10646  Companhia Aérea: GOL, Localizador: FLXNAO. Pas...            3140.46
# 10647  Companhia Aérea: AZUL, Localizador: TKR98A. Pa...            2850.90
#
#        COD_DOCUMENTO
# 10643        2184750
# 10644        2184748
# 10645        2184892
# 10646        2185426
# 10647        2185429

# %% [markdown]
# # Avaliando dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63199 entries, 0 to 10647
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                63199 non-null  int64
#  1   MES                63199 non-null  int64
#  2   SENADOR            63199 non-null  object
#  3   TIPO_DESPESA       63199 non-null  object
#  4   CNPJ_CPF           63199 non-null  object
#  5   FORNECEDOR         63199 non-null  object
#  6   DOCUMENTO          60584 non-null  object
#  7   DATA               63199 non-null  object
#  8   DETALHAMENTO       35211 non-null  object
#  9   VALOR_REEMBOLSADO  63199 non-null  float64
#  10  COD_DOCUMENTO      63199 non-null  int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 5.8+ MB

# %% [markdown]
# O dataset completo de 2019 até 2022 contém 11 colunas e 68828 linhas.

# %%
duplicados = dataset.duplicated()
duplicados.sum()
# Out:
# 0

# %% [markdown]
# A princípio, o dataset completo não contém dados duplicados.

# %%
nulos = dataset.isnull()
nulos.sum()
# Out:
# ANO                      0
# MES                      0
# SENADOR                  0
# TIPO_DESPESA             0
# CNPJ_CPF                 0
# FORNECEDOR               0
# DOCUMENTO             2615
# DATA                     0
# DETALHAMENTO         27988
# VALOR_REEMBOLSADO        0
# COD_DOCUMENTO            0
# dtype: int64

# %% [markdown]
# O dataset contém 2592 dados nulos na coluna DOCUMENTO e 27871 dados nulos na coluna DETALHAMENTO.

# %% [markdown]
# Sepadano dados nulos da coluna DETALHAMENTO para melhor avaliação:

# %%
detalhamento_nulo = dataset[dataset['DETALHAMENTO'].isna()]

# %%
detalhamento_nulo[['ANO','SENADOR', 'TIPO_DESPESA', 'DETALHAMENTO', 'VALOR_REEMBOLSADO']].sample(30)
# Out:
#         ANO             SENADOR  \
# 15803  2019  RANDOLFE RODRIGUES
# 4226   2022            GIORDANO
# 1607   2020        CARLOS VIANA
# 17265  2019    ROGÉRIO CARVALHO
# 1066   2020        CARLOS VIANA
# 7590   2022        NILDA GONDIM
# 15649  2019      PLÍNIO VALÉRIO
# 12952  2021     RENAN CALHEIROS
# 10074  2021       MAJOR OLIMPIO
# 7809   2020       MAJOR OLIMPIO
# 12925  2021     RENAN CALHEIROS
# 7339   2020  LUIS CARLOS HEINZE
# 4799   2020               IRAJÁ
# 20920  2019        ZENAIDE MAIA
# 20549  2019      WEVERTON ROCHA
# 3428   2022     FERNANDO COLLOR
# 7285   2020  LUIS CARLOS HEINZE
# 12226  2020    SORAYA THRONICKE
# 1190   2020        CARLOS VIANA
# 16780  2019     RODRIGO PACHECO
# 518    2022       CARLOS FÁVARO
# 11463  2019  LUIS CARLOS HEINZE
# 7876   2021    JEAN PAUL PRATES
# 626    2022       CARLOS FÁVARO
# 3758   2019       EDUARDO BRAGA
# 15737  2019  RANDOLFE RODRIGUES
# 4286   2021     ESPERIDIÃO AMIN
# 7941   2021    JEAN PAUL PRATES
# 7878   2019  JARBAS VASCONCELOS
# 125    2022   ALESSANDRO VIEIRA
#
#                                             TIPO_DESPESA DETALHAMENTO  \
# 15803  Locomoção, hospedagem, alimentação, combustíve...          NaN
# 4226   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 1607   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 17265  Aluguel de imóveis para escritório político, c...          NaN
# 1066   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 7590   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 15649  Locomoção, hospedagem, alimentação, combustíve...          NaN
# 12952  Locomoção, hospedagem, alimentação, combustíve...          NaN
# 10074  Locomoção, hospedagem, alimentação, combustíve...          NaN
# 7809   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 12925  Aluguel de imóveis para escritório político, c...          NaN
# 7339   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 4799   Aluguel de imóveis para escritório político, c...          NaN
# 20920                Divulgação da atividade parlamentar          NaN
# 20549  Locomoção, hospedagem, alimentação, combustíve...          NaN
# 3428   Contratação de consultorias, assessorias, pesq...          NaN
# 7285   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 12226  Aquisição de material de consumo para uso no e...          NaN
# 1190   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 16780  Locomoção, hospedagem, alimentação, combustíve...          NaN
# 518    Aluguel de imóveis para escritório político, c...          NaN
# 11463  Locomoção, hospedagem, alimentação, combustíve...          NaN
# 7876   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 626    Locomoção, hospedagem, alimentação, combustíve...          NaN
# 3758   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 15737  Aluguel de imóveis para escritório político, c...          NaN
# 4286   Aquisição de material de consumo para uso no e...          NaN
# 7941   Locomoção, hospedagem, alimentação, combustíve...          NaN
# 7878   Aluguel de imóveis para escritório político, c...          NaN
# 125    Contratação de consultorias, assessorias, pesq...          NaN
#
#        VALOR_REEMBOLSADO
# 15803             484.00
# 4226              195.02
# 1607              140.00
# 17265            1310.38
# 1066              190.19
# 7590              100.00
# 15649             232.20
# 12952             338.80
# 10074             165.24
# 7809             1887.12
# 12925             229.80
# 7339              150.00
# 4799              127.14
# 20920            2000.00
# 20549             216.19
# 3428             8000.00
# 7285              282.40
# 12226             145.40
# 1190               72.00
# 16780             219.81
# 518              3700.00
# 11463             115.00
# 7876              300.09
# 626               172.00
# 3758             1492.70
# 15737             677.12
# 4286              439.90
# 7941              330.01
# 7878             3000.00
# 125              6400.00

# %% [markdown]
# Sepadano dados nulos da coluna DOCUMENTO para melhor avaliação:

# %%
documento_nulo = dataset[dataset['DOCUMENTO'].isna()]

# %%
documento_nulo[['ANO','SENADOR', 'TIPO_DESPESA', 'DETALHAMENTO', 'DOCUMENTO', 'VALOR_REEMBOLSADO']].sample(30)
# Out:
#         ANO                  SENADOR  \
# 1024   2019        ANTONIO ANASTASIA
# 3289   2022  FERNANDO BEZERRA COELHO
# 8078   2021           JORGINHO MELLO
# 18048  2019             SIMONE TEBET
# 6547   2020               JOSÉ SERRA
# 4860   2021        FABIANO CONTARATO
# 3021   2022        FABIANO CONTARATO
# 13908  2019     MARIA DO CARMO ALVES
# 17224  2019         ROGÉRIO CARVALHO
# 8772   2022         ROGÉRIO CARVALHO
# 13566  2020             ZENAIDE MAIA
# 10742  2020            ROBERTO ROCHA
# 5948   2022               JOSÉ SERRA
# 3346   2022  FERNANDO BEZERRA COELHO
# 3327   2021          DAVI ALCOLUMBRE
# 4907   2021        FABIANO CONTARATO
# 8623   2021               JOSÉ SERRA
# 5304   2020            JAQUES WAGNER
# 7256   2021       JARBAS VASCONCELOS
# 3684   2019            EDUARDO BRAGA
# 3624   2021            EDUARDO GOMES
# 13641  2020             ZENAIDE MAIA
# 4729   2021        FABIANO CONTARATO
# 2960   2020            EDUARDO GOMES
# 2886   2020            EDUARDO GOMES
# 3706   2019            EDUARDO BRAGA
# 3392   2022  FERNANDO BEZERRA COELHO
# 12918  2021          RENAN CALHEIROS
# 3921   2019            EDUARDO GOMES
# 5732   2021                 GIORDANO
#
#                                             TIPO_DESPESA  \
# 1024   Aluguel de imóveis para escritório político, c...
# 3289   Locomoção, hospedagem, alimentação, combustíve...
# 8078   Aquisição de material de consumo para uso no e...
# 18048  Aluguel de imóveis para escritório político, c...
# 6547   Aluguel de imóveis para escritório político, c...
# 4860   Locomoção, hospedagem, alimentação, combustíve...
# 3021   Aluguel de imóveis para escritório político, c...
# 13908  Aluguel de imóveis para escritório político, c...
# 17224  Aluguel de imóveis para escritório político, c...
# 8772   Aluguel de imóveis para escritório político, c...
# 13566  Aluguel de imóveis para escritório político, c...
# 10742  Aluguel de imóveis para escritório político, c...
# 5948   Aluguel de imóveis para escritório político, c...
# 3346   Locomoção, hospedagem, alimentação, combustíve...
# 3327   Aluguel de imóveis para escritório político, c...
# 4907   Locomoção, hospedagem, alimentação, combustíve...
# 8623   Aluguel de imóveis para escritório político, c...
# 5304   Aluguel de imóveis para escritório político, c...
# 7256   Aluguel de imóveis para escritório político, c...
# 3684   Locomoção, hospedagem, alimentação, combustíve...
# 3624   Aluguel de imóveis para escritório político, c...
# 13641  Aluguel de imóveis para escritório político, c...
# 4729   Locomoção, hospedagem, alimentação, combustíve...
# 2960   Aluguel de imóveis para escritório político, c...
# 2886   Aluguel de imóveis para escritório político, c...
# 3706   Locomoção, hospedagem, alimentação, combustíve...
# 3392   Locomoção, hospedagem, alimentação, combustíve...
# 12918  Aluguel de imóveis para escritório político, c...
# 3921   Aluguel de imóveis para escritório político, c...
# 5732   Locomoção, hospedagem, alimentação, combustíve...
#
#                                             DETALHAMENTO DOCUMENTO  \
# 1024                                                 NaN       NaN
# 3289   Despesa com serviços de uber para o servidor -...       NaN
# 8078                                                 NaN       NaN
# 18048  Pagamento de despesas com aluguel das salas 10...       NaN
# 6547   Senador José Serra - Despesa referente ao paga...       NaN
# 4860   DESPESA COM SERVIÇOS DE TRANSPORTE PRIVADO MED...       NaN
# 3021   DESPESA COM ALUGUEL DAS INSTALAÇÕES DO ESCRITÓ...       NaN
# 13908                                                NaN       NaN
# 17224                                                NaN       NaN
# 8772                                                 NaN       NaN
# 13566                                                NaN       NaN
# 10742  Recibo de aluguel do imóvel destinado ao escri...       NaN
# 5948   Senador José Serra - Despesa referente ao paga...       NaN
# 3346               Despesa com Transporte - Uber - 05/22       NaN
# 3327   Despesa com pagamento de aluguel de imóvel par...       NaN
# 4907   Despesa com serviços de transporte privado urb...       NaN
# 8623   Senador José Serra - Despesa referente ao paga...       NaN
# 5304   REF. A COTA 10/11 DO IPTU DO ESCRITÓRIO POLÍTI...       NaN
# 7256                                                 NaN       NaN
# 3684                                                 NaN       NaN
# 3624   DESPESA COM ALUGUEL DE IMÓVEL QUE SERVE O SENA...       NaN
# 13641                                                NaN       NaN
# 4729   DESPESA COM SERVIÇOS DE TRANSPORTE PRIVADO URB...       NaN
# 2960   DESPESA COM ALUGUEL DE IMÓVEL QUE SERVE O SENA...       NaN
# 2886   DESPESA COM TRIBUTOS CONCERNENTES AO IMÓVEL QU...       NaN
# 3706                                                 NaN       NaN
# 3392   Despesas com serviços de transporte da servido...       NaN
# 12918                                                NaN       NaN
# 3921   Referente a locação do escritório de apoio a a...       NaN
# 5732                                                 NaN       NaN
#
#        VALOR_REEMBOLSADO
# 1024             2223.33
# 3289               33.09
# 8078               48.90
# 18048            3974.30
# 6547              272.07
# 4860                8.90
# 3021             3527.34
# 13908              69.27
# 17224             303.44
# 8772             4500.00
# 13566            2500.00
# 10742            6000.00
# 5948              296.53
# 3346               29.30
# 3327             3600.00
# 4907               60.98
# 8623              269.57
# 5304              196.07
# 7256             3200.00
# 3684               20.00
# 3624             1800.00
# 13641            2500.00
# 4729               37.12
# 2960             1800.00
# 2886              103.68
# 3706               22.00
# 3392               10.95
# 12918              98.95
# 3921             3900.00
# 5732              178.43

# %% [markdown]
# ## Conclusão da avaliação

# %% [markdown]
# Após avaliação, me parece sensato remover as colunas DOCUMENTO e DETALHAMENTO pois ambas contém excesso de valores nulos e o conteúdo de ambas não me parece ser de grande valia para nosso estudo, pois são variáveis descritivas, que não possuem padrão ou são informações redundantes de outros campos (como localizadores de passagens aéreas ou detalhamento mais específico da coluna 'TIPO_DE_DESPESA').

# %%
dados = dataset.drop(['DOCUMENTO', 'DETALHAMENTO'], axis=1)

# %% [markdown]
# Reorganizando índice:

# %%
dados.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# Verificando typos no nome dos senadores:

# %%
dados.SENADOR.unique()
# Out:
# array(['ACIR GURGACZ', 'AÉCIO NEVES', 'ALESSANDRO VIEIRA',
#        'ALOYSIO NUNES FERREIRA', 'ALVARO DIAS', 'ANA AMÉLIA',
#        'ÂNGELA PORTELA', 'ANGELO CORONEL', 'ANTONIO ANASTASIA',
#        'ANTÔNIO CARLOS VALADARES', 'ARMANDO MONTEIRO',
#        'AROLDE DE OLIVEIRA', 'ATAÍDES OLIVEIRA', 'BENEDITO DE LIRA',
#        'BLAIRO MAGGI', 'CARLOS VIANA', 'CÁSSIO CUNHA LIMA',
#        'CHICO RODRIGUES', 'CID GOMES', 'CIRO NOGUEIRA', 'CONFÚCIO MOURA',
#        'DALIRIO BEBER', 'DANIELLA RIBEIRO', 'DÁRIO BERGER',
#        'DAVI ALCOLUMBRE', 'EDISON LOBÃO', 'EDUARDO AMORIM',
#        'EDUARDO BRAGA', 'EDUARDO GIRÃO', 'EDUARDO GOMES', 'ELIZIANE GAMA',
#        'ELMANO FÉRRER', 'ESPERIDIÃO AMIN', 'FABIANO CONTARATO',
#        'FERNANDO BEZERRA COELHO', 'FERNANDO COLLOR', 'FLÁVIO ARNS',
#        'FLÁVIO BOLSONARO', 'FLEXA RIBEIRO', 'GARIBALDI ALVES FILHO',
#        'GLEISI HOFFMANN', 'GUARACY SILVEIRA', 'HÉLIO JOSÉ',
#        'HUMBERTO COSTA', 'IRAJÁ', 'IVO CASSOL', 'IZALCI LUCAS',
#        'JADER BARBALHO', 'JAQUES WAGNER', 'JARBAS VASCONCELOS',
#        'JAYME CAMPOS', 'JEAN PAUL PRATES', 'JOÃO ALBERTO SOUZA',
#        'JOÃO CAPIBERIBE', 'JORGE VIANA', 'JORGINHO MELLO',
#        'JOSÉ AGRIPINO', 'JOSÉ MARANHÃO', 'JOSÉ MEDEIROS', 'JOSÉ PIMENTEL',
#        'JOSÉ SERRA', 'JUÍZA SELMA', 'KÁTIA ABREU', 'LASIER MARTINS',
#        'LÍDICE DA MATA', 'LINDBERGH FARIAS', 'LUCAS BARRETO',
#        'LÚCIA VÂNIA', 'LUIS CARLOS HEINZE', 'LUIZ CARLOS DO CARMO',
#        'LUIZ PASTORE', 'MAGNO MALTA', 'MAILZA GOMES', 'MAJOR OLIMPIO',
#        'MARA GABRILLI', 'MARCELO CASTRO', 'MARCIO BITTAR',
#        'MARCOS DO VAL', 'MARCOS ROGÉRIO', 'MARIA DO CARMO ALVES',
#        'MARTA SUPLICY', 'MECIAS DE JESUS', 'NELSINHO TRAD', 'OMAR AZIZ',
#        'ORIOVISTO GUIMARÃES', 'OTTO ALENCAR', 'PAULO ALBUQUERQUE',
#        'PAULO BAUER', 'PAULO PAIM', 'PAULO ROCHA',
#        'PEDRO CHAVES DOS SANTOS FILHO', 'PLÍNIO VALÉRIO',
#        'PRISCO BEZERRA', 'RAIMUNDO LIRA', 'RANDOLFE RODRIGUES',
#        'RENAN CALHEIROS', 'RENILDE BULHÕES', 'RICARDO FERRAÇO',
#        'ROBERTO REQUIÃO', 'ROBERTO ROCHA', 'RODRIGO CUNHA',
#        'RODRIGO PACHECO', 'ROGÉRIO CARVALHO', 'ROMÁRIO', 'ROMERO JUCÁ',
#        'ROSE DE FREITAS', 'SÉRGIO PETECÃO', 'SIMONE TEBET',
#        'SIQUEIRA CAMPOS', 'SORAYA THRONICKE', 'STYVENSON VALENTIM',
#        'TASSO JEREISSATI', 'TELMÁRIO MOTA', 'VALDIR RAUPP',
#        'VANDERLAN CARDOSO', 'VANESSA GRAZZIOTIN',
#        'VENEZIANO VITAL DO RÊGO', 'VICENTINHO ALVES', 'WALDEMIR MOKA',
#        'WALTER PINHEIRO', 'WELLINGTON FAGUNDES', 'WEVERTON ROCHA',
#        'WILDER MORAIS', 'ZÉ SANTANA', 'ZENAIDE MAIA', 'ZEQUINHA MARINHO',
#        'ZEZÉ PERRELLA', 'CARLOS FÁVARO', 'CARLOS PORTINHO',
#        'DIEGO TAVARES', 'NEY SUASSUNA', 'CHIQUINHO FEITOSA',
#        'ELIANE NOGUEIRA', 'GIORDANO', 'JOSÉ ANÍBAL',
#        'MARIA ELIZA DE AGUIAR E SILVA', 'NAILDE PANTA', 'NILDA GONDIM',
#        'VIRGINIO DE CARVALHO', 'ALEXANDRE SILVEIRA', 'DRA. EUDÓCIA',
#        'EDUARDO VELLOSO', 'FABIO GARCIA', 'MARGARETH BUZETTI',
#        'MARIA DAS VITÓRIAS', 'OGARI PACHECO', 'RAFAEL TENÓRIO',
#        'ROBERTH BRINGEL'], dtype=object)

# %%
print(f'Existem ao todo, {len(dados.SENADOR.unique())} senadores distribuidos nos 4 anos de 2019 a 2022.')
# Out:
# Existem ao todo, 148 senadores distribuidos nos 4 anos de 2019 a 2022.

# %% [markdown]
# Convertendo campo DATA para datetime:

# %%
dados['DATA'] = pd.to_datetime(dados['DATA'], format='%d/%m/%Y', errors='coerce')

# %% [markdown]
# Procurando por valores nulos no campo DATA após conversão:

# %%
dados[dados['DATA'].isnull()]
# Out:
#         ANO  MES         SENADOR  \
# 10986  2019    1     LÚCIA VÂNIA
# 31996  2020    5  PLÍNIO VALÉRIO
# 37872  2021   11    CARLOS VIANA
#
#                                             TIPO_DESPESA            CNPJ_CPF  \
# 10986  Aluguel de imóveis para escritório político, c...  08.573.731/0001-38
# 31996                Divulgação da atividade parlamentar  27.209.437/0001-96
# 37872  Passagens aéreas, aquáticas e terrestres nacio...  16.978.175/0001-08
#
#                                               FORNECEDOR DATA  \
# 10986  LDE Contabilidade e Administração de Condomíni...  NaT
# 31996                 Excelsior Comunicação Digital Ltda  NaT
# 37872                       ADRIA VIAGENS E TURISMO LTDA  NaT
#
#        VALOR_REEMBOLSADO  COD_DOCUMENTO
# 10986             271.26        2114251
# 31996            1150.00        2144535
# 37872             339.90        2169237

# %% [markdown]
# Procurando o motivo por estes registros retornarem como nulo:

# %%
dataset.loc[(dataset['SENADOR'] == 'LÚCIA VÂNIA') & (dataset['COD_DOCUMENTO'] == 2114251)]
# Out:
#         ANO  MES      SENADOR  \
# 10986  2019    1  LÚCIA VÂNIA
#
#                                             TIPO_DESPESA            CNPJ_CPF  \
# 10986  Aluguel de imóveis para escritório político, c...  08.573.731/0001-38
#
#                                               FORNECEDOR DOCUMENTO  \
# 10986  LDE Contabilidade e Administração de Condomíni...   0107007
#
#              DATA      DETALHAMENTO  VALOR_REEMBOLSADO  COD_DOCUMENTO
# 10986  31/01/0219  Taxa condominial             271.26        2114251

# %%
dataset.loc[(dataset['SENADOR'] == 'PLÍNIO VALÉRIO') & (dataset['COD_DOCUMENTO'] == 2144535)]
# Out:
#         ANO  MES         SENADOR                         TIPO_DESPESA  \
# 10362  2020    5  PLÍNIO VALÉRIO  Divulgação da atividade parlamentar
#
#                  CNPJ_CPF                          FORNECEDOR DOCUMENTO  \
# 10362  27.209.437/0001-96  Excelsior Comunicação Digital Ltda    2020/9
#
#              DATA DETALHAMENTO  VALOR_REEMBOLSADO  COD_DOCUMENTO
# 10362  05/05/0202          NaN             1150.0        2144535

# %%
dataset.loc[(dataset['SENADOR'] == 'CARLOS VIANA') & (dataset['COD_DOCUMENTO'] == 2169237)]
# Out:
#        ANO  MES       SENADOR  \
# 2148  2021   11  CARLOS VIANA
#
#                                            TIPO_DESPESA            CNPJ_CPF  \
# 2148  Passagens aéreas, aquáticas e terrestres nacio...  16.978.175/0001-08
#
#                         FORNECEDOR DOCUMENTO        DATA  \
# 2148  ADRIA VIAGENS E TURISMO LTDA    YK1QHD  29/10/0202
#
#                                            DETALHAMENTO  VALOR_REEMBOLSADO  \
# 2148  Companhia Aérea: AZUL, Localizador: YK1QHD. Pa...              339.9
#
#       COD_DOCUMENTO
# 2148        2169237

# %% [markdown]
# O ano das datas foi preenchido incorretamente. Corrigindo no dataset mais recente:

# %%
df = dados.iloc[10986].copy()
df['DATA'] = '2019-01-31'
dados.iloc[10986] = df

# %%
df = dados.iloc[31996].copy()
df['DATA'] = '2020-05-05'
dados.iloc[31996] = df

# %%
df = dados.iloc[37872].copy()
df['DATA'] = '2020-10-29'
dados.iloc[37872] = df

# %% [markdown]
# # Exploração dos dados

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63199 entries, 0 to 63198
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ANO                63199 non-null  int64
#  1   MES                63199 non-null  int64
#  2   SENADOR            63199 non-null  object
#  3   TIPO_DESPESA       63199 non-null  object
#  4   CNPJ_CPF           63199 non-null  object
#  5   FORNECEDOR         63199 non-null  object
#  6   DATA               63199 non-null  datetime64[ns]
#  7   VALOR_REEMBOLSADO  63199 non-null  float64
#  8   COD_DOCUMENTO      63199 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 4.3+ MB

# %%
dados.sample(20)
# Out:
#         ANO  MES                  SENADOR  \
# 31095  2020   12            NELSINHO TRAD
# 56904  2022    3           HUMBERTO COSTA
# 21971  2020    9        ALESSANDRO VIEIRA
# 2243   2019   10                CID GOMES
# 62523  2022    3      WELLINGTON FAGUNDES
# 1525   2019    5             CARLOS VIANA
# 43047  2021    5       JARBAS VASCONCELOS
# 19371  2019    6  VENEZIANO VITAL DO RÊGO
# 59736  2022    2           MARCOS ROGÉRIO
# 11261  2019    7       LUIS CARLOS HEINZE
# 11374  2019    9       LUIS CARLOS HEINZE
# 20133  2019    9      WELLINGTON FAGUNDES
# 551    2019    9              ALVARO DIAS
# 8005   2019    7       JARBAS VASCONCELOS
# 18033  2019    8             SIMONE TEBET
# 8144   2019   11       JARBAS VASCONCELOS
# 52225  2021    3         ZEQUINHA MARINHO
# 43957  2021    7           JORGINHO MELLO
# 48206  2021   10              PAULO ROCHA
# 32739  2020    3          RODRIGO PACHECO
#
#                                             TIPO_DESPESA            CNPJ_CPF  \
# 31095  Aluguel de imóveis para escritório político, c...  02.558.157/0001-62
# 56904  Locomoção, hospedagem, alimentação, combustíve...  11.963.931/0001-01
# 21971  Aluguel de imóveis para escritório político, c...  13.017.462/0001-63
# 2243   Passagens aéreas, aquáticas e terrestres nacio...  72.243.918/0001-72
# 62523  Locomoção, hospedagem, alimentação, combustíve...  04.473.193/0001-59
# 1525   Aluguel de imóveis para escritório político, c...      144.409.206-59
# 43047  Aluguel de imóveis para escritório político, c...      891.653.904-82
# 19371  Passagens aéreas, aquáticas e terrestres nacio...  33.937.681/0001-78
# 59736  Passagens aéreas, aquáticas e terrestres nacio...  33.937.681/0001-78
# 11261  Locomoção, hospedagem, alimentação, combustíve...  00.804.430/0001-66
# 11374  Locomoção, hospedagem, alimentação, combustíve...  17.188.733/0001-02
# 20133  Locomoção, hospedagem, alimentação, combustíve...  00.031.708/0001-00
# 551    Passagens aéreas, aquáticas e terrestres nacio...  16.978.175/0001-08
# 8005   Passagens aéreas, aquáticas e terrestres nacio...  16.978.175/0001-08
# 18033  Locomoção, hospedagem, alimentação, combustíve...  37.539.459/0001-78
# 8144   Locomoção, hospedagem, alimentação, combustíve...  21.280.350/0001-29
# 52225  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 43957  Passagens aéreas, aquáticas e terrestres nacio...  33.937.681/0001-78
# 48206  Passagens aéreas, aquáticas e terrestres nacio...  16.978.175/0001-08
# 32739  Locomoção, hospedagem, alimentação, combustíve...  20.415.295/0014-99
#
#                                               FORNECEDOR       DATA  \
# 31095                              Telefônica Brasil S/A 2020-12-04
# 56904                                Lima e Marques Ltda 2022-03-03
# 21971                                           ENERGISA 2020-09-14
# 2243                         SIAD VIAGENS E TURISMO LTDA 2019-10-08
# 62523                          Posto da Torre Eireli EPP 2022-03-31
# 1525                              WILSON MENDES FERREIRA 2019-06-03
# 43047              Marcelo Augusto Bruno Carneiro Leitão 2021-05-24
# 19371                                              LATAM 2019-06-10
# 59736                                              LATAM 2022-02-21
# 11261                 Comercial Combustiveis Lovato Ltda 2019-07-15
# 11374                             CONVENIENCIA MILLENIUM 2019-09-28
# 20133  Sindicato dos Permissionários de Táxis e Motor... 2019-09-26
# 551                              Ádria Viagens e Turismo 2019-09-16
# 8005                        ADRIA VIAGENS E TURISMO LTDA 2019-06-26
# 18033                                POSTO EMANUELE LTDA 2019-08-19
# 8144                     POSTO SÃO FÉLIX ESPINHEIRO LTDA 2019-11-21
# 52225                                      Exceller Tour 2021-03-03
# 43957                                              LATAM 2021-06-25
# 48206                       Adria Viagens e Turismo Ltda 2021-10-20
# 32739                           REDE DOM PEDRO DE POSTOS 2020-03-31
#
#        VALOR_REEMBOLSADO  COD_DOCUMENTO
# 31095             542.98        2153625
# 56904             187.02        2176139
# 21971             221.28        2149561
# 2243             1082.87        2134820
# 62523             100.00        2177648
# 1525             6700.00        2122063
# 43047            3200.00        2160396
# 19371             826.79        2126276
# 59736            2253.33        2175938
# 11261              81.70        2126454
# 11374              17.00        2131877
# 20133              13.00        2131742
# 551               994.24        2131216
# 8005              501.44        2126960
# 18033             250.97        2131613
# 8144             1072.92        2136235
# 52225            1880.03        2156563
# 43957            1238.64        2162764
# 48206            2202.32        2168667
# 32739             256.44        2144784

# %% [markdown]
# # Dia 2 - Data Visualization & Storytelling

# %% [markdown]
# O que você achou do primeiro desafio, Tarik Pomim?
#
# Um bom aquecimento, certo?
#
# Agora, é hora de mergulhar no segundo!
#
# Ontem você trabalhou com um dataset que necessitava de muita limpeza e tratamento. Agora é a hora divertida: eu proponho que você conte uma história a partir dos dados desse dataset.
#
# Mas, vamos por partes!
#
# A comunicação é uma das habilidades mais importantes de um Cientista de Dados.
#
# Saber comunicar efetivamente os seus resultados de uma forma que pessoas de negócio e não-técnicas consigam entender é uma das soft skills mais apreciadas do mercado, e também uma das mais difíceis de dominar.
#
# Uma das formas mais efetivas de se comunicar está em uma técnica chamada Storytelling (Contar histórias, em tradução livre).
#
# Isto é, criar uma narrativa sobre seu trabalho para que seja mais fácil entender seu raciocínio e entender seus resultados.
#
# E quando falamos em Storytelling, não podemos esquecer de seu melhor amigo: a visualização de dados.
#
# A combinação de bons gráficos e visualizações com uma história bem contada, é capaz de fazer qualquer audiência entender os resultados do seu trabalho — seja a explicação do resultado de um teste de hipótese ou análise estatística, ou mesmo a comunicação dos resultados do seu modelo de Machine Learning.
#
# Eu te proponho: comece a investigar os seus dados e gerar visualizações para identificar padrões estranhos ou estatísticas interessantes.
#
# Pense em perguntas que os dados podem responder.
#
# Por exemplo: se você pegou o dataset do CEAPS, você consegue ver qual foi o senador que mais declarou despesas? Qual foi o percentual da cota que os senadores gastaram? Teve algum com mais de 90%? Em ano de eleições os senadores gastam mais? Dentre outras perguntas.
#
# Você pode começar gerando algumas estatísticas bem simples, como contar valores de alguma coluna, somá-los, fazer agrupamentos, ordená-los etc.
#
# A partir dessas análises macro, você conseguirá afunilar e achar uma boa história.

# %% [markdown]
# ## Dica

# %% [markdown]
# Para gerar os gráficos, existem diversas ferramentas de visualizações de dados.
#
# Minha recomendação é que você use o Plotly: uma biblioteca de visualizações de dados que, além de criar gráficos lindos, permite que você interaja com eles. Essa é a biblioteca que eu uso quando faço meus storytellings.
#
# No meu blog .[eu já fiz um post sobre como usar essa poderosa ferramenta](https://paulovasconcellos.com.br/como-criar-gr%C3%A1ficos-interativos-utilizando-plotly-e-python-3eb6eda57a2b)
#
# Uma dica importante ao contar histórias é diminuir ao máximo a carga cognitiva da sua audiência. Em outras palavras, você não quer que seus espectadores pensem muito.
#
# Às vezes, um gráfico simples e bem feito é capaz de explicar vários minutos sobre o que significa o eixo X e Y. Tente abstrair ao máximo os conceitos técnicos.
#
# Existem muitas ferramentas que você pode usar para contar sua história. O Jupyter Notebook é onde você provavelmente colocará seu código e irá gerar os gráficos, mas não precisa necessariamente colocar sua apresentação lá.
#
# Você pode pegar os gráficos e colocar em um PowerPoint ou Google Presentations, por exemplo.
#
# O próprio Jupyter Notebook é uma opção, mas tenha em mente que a ferramenta de apresentação que você vai escolher deve refletir a audiência para a qual você vai se apresentar.
#
# Por exemplo: para pessoas técnicas (principalmente outros Data Scientists) Jupyter Notebooks são mais que suficientes, mas para apresentar para seu CEO, mostrar um monte de código entre os seus markdowns talvez não seja a melhor opção. Lembre-se: diminua a carga cognitiva da sua audiência.

# %% [markdown]
# ## Extra

# %% [markdown]
# Que tal criar um post no Medium ou Dev.to sobre a história que você está contando? Blog posts são bons exemplos de ferramentas para contar histórias.
#
# [Recomendo a leitura desse post que fiz no Medium sobre Data Storytelling](https://paulovasconcellos.com.br/o-que-%C3%A9-data-storytelling-ac5a924dcdaf), para que você tenha uma melhor noção sobre como pode extrair o máximo dessa habilidade.
#
# Uma ótima referência de storytelling é o [blog do Storytelling with Data](https://www.storytellingwithdata.com/blog), que possui um livro de mesmo nome, considerada a bíblia da visualização de dados.

# %% [markdown]
# ## Separando apenas valor reembolsado por ano

# %% [markdown]
# Deixando de lado colunas exceto a do valor reembolsado:

# %%
df = dados.drop(['MES', 'TIPO_DESPESA', 'CNPJ_CPF', 'FORNECEDOR', 'DATA', 'COD_DOCUMENTO'], axis=1)
df.head(30)
# Out:
#      ANO       SENADOR  VALOR_REEMBOLSADO
# 0   2019  ACIR GURGACZ              66.02
# 1   2019  ACIR GURGACZ             139.98
# 2   2019  ACIR GURGACZ            6000.00
# 3   2019  ACIR GURGACZ             316.39
# 4   2019  ACIR GURGACZ              99.45
# 5   2019  ACIR GURGACZ             262.93
# 6   2019  ACIR GURGACZ            6000.00
# 7   2019  ACIR GURGACZ             317.36
# 8   2019  ACIR GURGACZ              85.50
# 9   2019  ACIR GURGACZ             244.57
# 10  2019  ACIR GURGACZ            6000.00
# 11  2019  ACIR GURGACZ             321.39
# 12  2019  ACIR GURGACZ            1000.00
# 13  2019  ACIR GURGACZ            1500.00
# 14  2019  ACIR GURGACZ              88.07
# 15  2019  ACIR GURGACZ             317.43
# 16  2019  ACIR GURGACZ            6000.00
# 17  2019  ACIR GURGACZ             321.39
# 18  2019  ACIR GURGACZ             378.00
# 19  2019  ACIR GURGACZ             252.00
# 20  2019  ACIR GURGACZ            3500.00
# 21  2019  ACIR GURGACZ            1000.00
# 22  2019  ACIR GURGACZ            1500.00
# 23  2019  ACIR GURGACZ             825.00
# 24  2019  ACIR GURGACZ            2000.00
# 25  2019  ACIR GURGACZ              78.62
# 26  2019  ACIR GURGACZ             224.07
# 27  2019  ACIR GURGACZ            6000.00
# 28  2019  ACIR GURGACZ             321.39
# 29  2019  ACIR GURGACZ            1000.00

# %% [markdown]
# ### Valor Reembolsado por Senador em 2019

# %%
df_2019 = df[df['ANO']==2019].groupby('SENADOR', as_index=False).agg({"VALOR_REEMBOLSADO":"sum"})
df_2019.sort_values('SENADOR', inplace=True)
df_2019.rename(columns = {'VALOR_REEMBOLSADO':'TOTAL_2019'}, inplace = True)
df_2019
# Out:
#                     SENADOR  TOTAL_2019
# 0              ACIR GURGACZ   251714.02
# 1         ALESSANDRO VIEIRA   448395.92
# 2    ALOYSIO NUNES FERREIRA    18450.05
# 3               ALVARO DIAS   105354.33
# 4                ANA AMÉLIA    16596.83
# ..                      ...         ...
# 122            ZENAIDE MAIA   361706.70
# 123        ZEQUINHA MARINHO   444688.20
# 124           ZEZÉ PERRELLA     7961.09
# 125              ZÉ SANTANA    38678.43
# 126          ÂNGELA PORTELA    39411.85
#
# [127 rows x 2 columns]

# %% [markdown]
# ### Valor Reembolsado por Senador em 2020

# %%
df_2020 = df[df['ANO']==2020].groupby('SENADOR', as_index=False).agg({"VALOR_REEMBOLSADO":"sum"})
df_2020.sort_values('SENADOR', inplace=True)
df_2020.rename(columns = {'VALOR_REEMBOLSADO':'TOTAL_2020'}, inplace = True)
df_2020
# Out:
#                     SENADOR  TOTAL_2020
# 0              ACIR GURGACZ   415364.91
# 1         ALESSANDRO VIEIRA   292200.76
# 2               ALVARO DIAS    17371.41
# 3            ANGELO CORONEL   398094.72
# 4         ANTONIO ANASTASIA   239629.04
# ..                      ...         ...
# 79  VENEZIANO VITAL DO RÊGO   209841.57
# 80      WELLINGTON FAGUNDES   419966.92
# 81           WEVERTON ROCHA   333351.22
# 82             ZENAIDE MAIA   291152.47
# 83         ZEQUINHA MARINHO   390799.33
#
# [84 rows x 2 columns]

# %% [markdown]
# ### Valor Reembolsado por Senador em 2021

# %%
df_2021 = df[df['ANO']==2021].groupby('SENADOR', as_index=False).agg({"VALOR_REEMBOLSADO":"sum"})
df_2021.sort_values('SENADOR', inplace=True)
df_2021.rename(columns = {'VALOR_REEMBOLSADO':'TOTAL_2021'}, inplace = True)
df_2021
# Out:
#                  SENADOR  TOTAL_2021
# 0           ACIR GURGACZ   415374.00
# 1      ALESSANDRO VIEIRA   424669.76
# 2            ALVARO DIAS    27231.37
# 3         ANGELO CORONEL   422595.45
# 4      ANTONIO ANASTASIA   292639.53
# ..                   ...         ...
# 81  VIRGINIO DE CARVALHO     5720.56
# 82   WELLINGTON FAGUNDES   419147.83
# 83        WEVERTON ROCHA   446907.86
# 84          ZENAIDE MAIA   292967.39
# 85      ZEQUINHA MARINHO   470226.88
#
# [86 rows x 2 columns]

# %% [markdown]
# ### Valor Reembolsado por Senador em 2022

# %%
df_2022 = df[df['ANO']==2022].groupby('SENADOR', as_index=False).agg({"VALOR_REEMBOLSADO":"sum"})
df_2022.sort_values('SENADOR', inplace=True)
df_2022.rename(columns = {'VALOR_REEMBOLSADO':'TOTAL_2022'}, inplace = True)
df_2022
# Out:
#                     SENADOR  TOTAL_2022
# 0              ACIR GURGACZ   275816.75
# 1         ALESSANDRO VIEIRA   266178.77
# 2        ALEXANDRE SILVEIRA   149668.26
# 3               ALVARO DIAS    49769.20
# 4            ANGELO CORONEL   248089.31
# ..                      ...         ...
# 84  VENEZIANO VITAL DO RÊGO   160244.30
# 85      WELLINGTON FAGUNDES   166369.78
# 86           WEVERTON ROCHA   229764.16
# 87             ZENAIDE MAIA   230592.42
# 88         ZEQUINHA MARINHO   252682.08
#
# [89 rows x 2 columns]

# %% [markdown]
# ### Totais dos valores reembolsados, por Senador

# %% [markdown]
# Criando novo dataframe com nomes de todos os senadores:

# %%
senadores = pd.DataFrame(dados.SENADOR.unique(), columns=['SENADOR']).sort_values(by='SENADOR').reset_index(drop=True)

# %% [markdown]
# Juntando os dataframes dos respectivos anos:

# %%
total_por_ano = senadores.merge(df_2019, on='SENADOR', how='left').merge(df_2020, on='SENADOR', how='left').merge(df_2021, on='SENADOR', how='left').merge(df_2022, on='SENADOR', how='left')

# %% [markdown]
# Preenchendo NaN com zeros:

# %%
total_por_ano.fillna(0, inplace=True)

# %% [markdown]
# Criando coluna com a soma total de todos os anos:

# %%
total_por_ano['SOMA_TOTAL'] = total_por_ano['TOTAL_2019'] + total_por_ano['TOTAL_2020'] + total_por_ano['TOTAL_2021'] + total_por_ano['TOTAL_2022']

# %%
total_por_ano.head(20)
# Out:
#                      SENADOR  TOTAL_2019  TOTAL_2020  TOTAL_2021  TOTAL_2022  \
# 0               ACIR GURGACZ   251714.02   415364.91   415374.00   275816.75
# 1          ALESSANDRO VIEIRA   448395.92   292200.76   424669.76   266178.77
# 2         ALEXANDRE SILVEIRA        0.00        0.00        0.00   149668.26
# 3     ALOYSIO NUNES FERREIRA    18450.05        0.00        0.00        0.00
# 4                ALVARO DIAS   105354.33    17371.41    27231.37    49769.20
# 5                 ANA AMÉLIA    16596.83        0.00        0.00        0.00
# 6             ANGELO CORONEL   339038.63   398094.72   422595.45   248089.31
# 7          ANTONIO ANASTASIA   305573.81   239629.04   292639.53    19647.13
# 8   ANTÔNIO CARLOS VALADARES    41844.45        0.00        0.00        0.00
# 9           ARMANDO MONTEIRO    34974.54        0.00        0.00        0.00
# 10        AROLDE DE OLIVEIRA   329547.92    99536.09        0.00        0.00
# 11          ATAÍDES OLIVEIRA    24621.58        0.00        0.00        0.00
# 12               AÉCIO NEVES    19739.01        0.00        0.00        0.00
# 13          BENEDITO DE LIRA     8508.78        0.00        0.00        0.00
# 14              BLAIRO MAGGI     8543.95        0.00        0.00        0.00
# 15             CARLOS FÁVARO        0.00   219377.18   419058.03   198744.23
# 16           CARLOS PORTINHO        0.00    61511.31   381712.78   241055.94
# 17              CARLOS VIANA   285508.12   335592.83   341954.40   221290.84
# 18           CHICO RODRIGUES   421313.68   345417.85   387278.17   328781.60
# 19         CHIQUINHO FEITOSA        0.00        0.00    68604.88    54742.34
#
#     SOMA_TOTAL
# 0   1358269.68
# 1   1431445.21
# 2    149668.26
# 3     18450.05
# 4    199726.31
# 5     16596.83
# 6   1407818.11
# 7    857489.51
# 8     41844.45
# 9     34974.54
# 10   429084.01
# 11    24621.58
# 12    19739.01
# 13     8508.78
# 14     8543.95
# 15   837179.44
# 16   684280.03
# 17  1184346.19
# 18  1482791.30
# 19   123347.22

# %% [markdown]
# # Storytelling e análises gráficas

# %% [markdown]
# Por exemplo: se você pegou o dataset do CEAPS, você consegue ver qual foi o senador que mais declarou despesas? Qual foi o percentual da cota que os senadores gastaram? Teve algum com mais de 90%? Em ano de eleições os senadores gastam mais? Dentre outras perguntas.
#
# Você pode começar gerando algumas estatísticas bem simples, como contar valores de alguma coluna, somá-los, fazer agrupamentos, ordená-los etc.

# %% [markdown]
# ## Qual foi o senador que mais declarou despesas?

# %% [markdown]
# ## Qual foi o percentual da cota que os senadores gastaram? Teve algum com mais de 90%?

# %% [markdown]
# ## Em ano de eleições os senadores gastam mais?

# %%
total_por_ano.head()
# Out:
#                   SENADOR  TOTAL_2019  TOTAL_2020  TOTAL_2021  TOTAL_2022  \
# 0            ACIR GURGACZ   251714.02   415364.91   415374.00   275816.75
# 1       ALESSANDRO VIEIRA   448395.92   292200.76   424669.76   266178.77
# 2      ALEXANDRE SILVEIRA        0.00        0.00        0.00   149668.26
# 3  ALOYSIO NUNES FERREIRA    18450.05        0.00        0.00        0.00
# 4             ALVARO DIAS   105354.33    17371.41    27231.37    49769.20
#
#    SOMA_TOTAL
# 0  1358269.68
# 1  1431445.21
# 2   149668.26
# 3    18450.05
# 4   199726.31

# %%
mais_gastadores = total_por_ano.sort_values(by='SOMA_TOTAL', ascending = False)

# %%
mais_gastadores.head(20)
# Out:
#                  SENADOR  TOTAL_2019  TOTAL_2020  TOTAL_2021  TOTAL_2022  \
# 131        TELMÁRIO MOTA   485846.15   488459.41   488402.25   310469.70
# 121     ROGÉRIO CARVALHO   459892.50   486526.49   502132.23   310382.79
# 94       MECIAS DE JESUS   447968.95   487992.63   488693.40   309372.61
# 106          PAULO ROCHA   485114.40   474301.41   483888.13   273285.61
# 82          MAILZA GOMES   466253.40   398691.74   462275.83   309168.71
# 118        ROBERTO ROCHA   427376.29   409902.99   448543.76   281032.13
# 144     ZEQUINHA MARINHO   444688.20   390799.33   470226.88   252682.08
# 37         ELIZIANE GAMA   411292.61   391595.64   446413.04   297696.83
# 32         EDUARDO BRAGA   519561.65   341383.17   391082.53   292700.74
# 86         MARCIO BITTAR   426948.31   460225.99   465838.31   181106.90
# 60      JEAN PAUL PRATES   428313.79   359911.79   431714.40   287620.17
# 129       SÉRGIO PETECÃO   439589.13   401951.08   436338.94   222860.94
# 18       CHICO RODRIGUES   421313.68   345417.85   387278.17   328781.60
# 57         JAQUES WAGNER   388340.70   403363.61   424638.93   262568.82
# 100            OMAR AZIZ   531315.99    74958.90   527681.31   328273.98
# 1      ALESSANDRO VIEIRA   448395.92   292200.76   424669.76   266178.77
# 140  WELLINGTON FAGUNDES   419037.61   419966.92   419147.83   166369.78
# 88        MARCOS ROGÉRIO   338260.32   415732.37   412541.11   244111.45
# 6         ANGELO CORONEL   339038.63   398094.72   422595.45   248089.31
# 96         NELSINHO TRAD   361870.44   394862.40   394819.82   252351.86
#
#      SOMA_TOTAL
# 131  1773177.51
# 121  1758934.01
# 94   1734027.59
# 106  1716589.55
# 82   1636389.68
# 118  1566855.17
# 144  1558396.49
# 37   1546998.12
# 32   1544728.09
# 86   1534119.51
# 60   1507560.15
# 129  1500740.09
# 18   1482791.30
# 57   1478912.06
# 100  1462230.18
# 1    1431445.21
# 140  1424522.14
# 88   1410645.25
# 6    1407818.11
# 96   1403904.52

# %% [markdown]
# ## Cotas parlementares por estado

# %% [markdown]
# ### Fonte

# %% [markdown]
# https://www2.camara.leg.br/comunicacao/assessoria-de-imprensa/guia-para-jornalistas/cota-parlamentar

# %% [markdown]
# ### Dados

# %% [markdown]
# Nome dos estados, por extenso:

# %%
estados = ['ACRE', 'ALAGOAS', 'AMAZONAS', 'AMAPA', 'BAHIA', 'CEARA', 'DISTRITO_FEDERAL', 'ESPIRITO_SANTO', 'GOIANIA', 'MARANHAO', 'MINAS_GERAIS', 'MATO_GROSSO_DO_SUL', 'MATO_GROSSO', 'PARA', 'PARAIBA', 'PERNANBUCO', 'PIAUI', 'PARANA', 'RIO_DE_JANEIRO', 'RIO_GRANDE_DO_NORTE', 'RONDONIA', 'RORAIMA', 'RIO_GRANDE_DO_SUL', 'SANTA_CATARINA', 'SERGIPE', 'SAO_PAULO', 'TOCANTINS']

# %% [markdown]
# Sigla dos estados:

# %%
siglas = ['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC', 'SE', 'SP', 'TO']

# %% [markdown]
# Cota parlamentar, mensal, em Reais (R$):

# %%
valor_mensal = [44632.46, 40944.10, 43570.12, 43374.78, 39010.85, 42451.77, 30788.66, 37423.91, 35507.06, 42151.69, 36092.71, 40542.84, 39428.03, 42227.45, 42032.56, 41676.80, 40971.77, 38871.86, 35759.97, 42731.99, 43672.49, 45612.53, 40875.90, 39877.78, 40139.26, 37043.53, 39503.61]

# %% [markdown]
# Gerando DataFrame:

# %%
cotas = pd.DataFrame(data={'ESTADOS': estados, 'SIGLAS': siglas, 'VALOR_MENSAL': valor_mensal})

# %% [markdown]
# Gerando coluna para valor total anual, em reais (R$):

# %%
cotas['TOTAL_ANO'] = cotas['VALOR_MENSAL'] * 12

# %% [markdown]
# Organizando por ordem alfabética:

# %%
cotas.sort_values('ESTADOS', inplace=True)

# %% [markdown]
# Resetando índice:

# %%
cotas.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### DataFrame final das cotas parlamentares por estado:

# %%
cotas
# Out:
#                 ESTADOS SIGLAS  VALOR_MENSAL  TOTAL_ANO
# 0                  ACRE     AC      44632.46  535589.52
# 1               ALAGOAS     AL      40944.10  491329.20
# 2                 AMAPA     AP      43374.78  520497.36
# 3              AMAZONAS     AM      43570.12  522841.44
# 4                 BAHIA     BA      39010.85  468130.20
# 5                 CEARA     CE      42451.77  509421.24
# 6      DISTRITO_FEDERAL     DF      30788.66  369463.92
# 7        ESPIRITO_SANTO     ES      37423.91  449086.92
# 8               GOIANIA     GO      35507.06  426084.72
# 9              MARANHAO     MA      42151.69  505820.28
# 10          MATO_GROSSO     MT      39428.03  473136.36
# 11   MATO_GROSSO_DO_SUL     MS      40542.84  486514.08
# 12         MINAS_GERAIS     MG      36092.71  433112.52
# 13                 PARA     PA      42227.45  506729.40
# 14              PARAIBA     PB      42032.56  504390.72
# 15               PARANA     PR      38871.86  466462.32
# 16           PERNANBUCO     PE      41676.80  500121.60
# 17                PIAUI     PI      40971.77  491661.24
# 18       RIO_DE_JANEIRO     RJ      35759.97  429119.64
# 19  RIO_GRANDE_DO_NORTE     RN      42731.99  512783.88
# 20    RIO_GRANDE_DO_SUL     RS      40875.90  490510.80
# 21             RONDONIA     RO      43672.49  524069.88
# 22              RORAIMA     RR      45612.53  547350.36
# 23       SANTA_CATARINA     SC      39877.78  478533.36
# 24            SAO_PAULO     SP      37043.53  444522.36
# 25              SERGIPE     SE      40139.26  481671.12
# 26            TOCANTINS     TO      39503.61  474043.32

# %% [markdown]
# ### Visualizações

# %%
cotas.columns
# Out:
# Index(['ESTADOS', 'SIGLAS', 'VALOR_MENSAL', 'TOTAL_ANO'], dtype='object')

# %%
cotas_maior_gasto_por_ano = cotas.sort_values('TOTAL_ANO', ascending=False)

# %%
import plotly.express as px

fig = px.bar(cotas_maior_gasto_por_ano,
             x="ESTADOS",
             y="TOTAL_ANO",
             orientation='v',
             title='Cota Parlamentar - Total anual por estado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ce33bc0a-7313-4a54-a0a6-fb82f47fc909" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce33bc0a-7313-4a54-a0a6-fb82f47fc909")) {                    Plotly.newPlot(                        "ce33bc0a-7313-4a54-a0a6-fb82f47fc909",                        [{"alignmentgroup":"True","hovertemplate":"ESTADOS=%{x}<br>TOTAL_ANO=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["RORAIMA","ACRE","RONDONIA","AMAZONAS","AMAPA","RIO_GRANDE_DO_NORTE","CEARA","PARA","MARANHAO","PARAIBA","PERNANBUCO","PIAUI","ALAGOAS","RIO_GRANDE_DO_SUL","MATO_GROSSO_DO_SUL","SERGIPE","SANTA_CATARINA","TOCANTINS","MATO_GROSSO","BAHIA","PARANA","ESPIRITO_SANTO","SAO_PAULO","MINAS_GERAIS","RIO_DE_JANEIRO","GOIANIA","DISTRITO_FEDERAL"],"xaxis":"x","y":[547350.36,535589.52,524069.88,522841.44000000006,520497.36,512783.88,509421.24,506729.39999999997,505820.28,504390.72,500121.60000000003,491661.24,491329.19999999995,490510.80000000005,486514.07999999996,481671.12,478533.36,474043.32,473136.36,468130.19999999995,466462.32,449086.92000000004,444522.36,433112.52,429119.64,426084.72,369463.92],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorsca ...

# %% [markdown]
# Segundo a fonte dos dados, o principal motivo da diferença das cotas parlamentares entre os estados é o custo das passagens aéreas para locomoção dos senadores até o Distrito Federal.

# %%
mais_gastadores.head(30)
# Out:
#                      SENADOR  TOTAL_2019  TOTAL_2020  TOTAL_2021  TOTAL_2022  \
# 131            TELMÁRIO MOTA   485846.15   488459.41   488402.25   310469.70
# 121         ROGÉRIO CARVALHO   459892.50   486526.49   502132.23   310382.79
# 94           MECIAS DE JESUS   447968.95   487992.63   488693.40   309372.61
# 106              PAULO ROCHA   485114.40   474301.41   483888.13   273285.61
# 82              MAILZA GOMES   466253.40   398691.74   462275.83   309168.71
# 118            ROBERTO ROCHA   427376.29   409902.99   448543.76   281032.13
# 144         ZEQUINHA MARINHO   444688.20   390799.33   470226.88   252682.08
# 37             ELIZIANE GAMA   411292.61   391595.64   446413.04   297696.83
# 32             EDUARDO BRAGA   519561.65   341383.17   391082.53   292700.74
# 86             MARCIO BITTAR   426948.31   460225.99   465838.31   181106.90
# 60          JEAN PAUL PRATES   428313.79   359911.79   431714.40   287620.17
# 129           SÉRGIO PETECÃO   439589.13   401951.08   436338.94   222860.94
# 18           CHICO RODRIGUES   421313.68   345417.85   387278.17   328781.60
# 57             JAQUES WAGNER   388340.70   403363.61   424638.93   262568.82
# 100                OMAR AZIZ   531315.99    74958.90   527681.31   328273.98
# 1          ALESSANDRO VIEIRA   448395.92   292200.76   424669.76   266178.77
# 140      WELLINGTON FAGUNDES   419037.61   419966.92   419147.83   166369.78
# 88            MARCOS ROGÉRIO   338260.32   415732.37   412541.11   244111.45
# 6             ANGELO CORONEL   339038.63   398094.72   422595.45   248089.31
# 96             NELSINHO TRAD   361870.44   394862.40   394819.82   252351.86
# 141           WEVERTON ROCHA   386665.17   333351.22   446907.86   229764.16
# 38             ELMANO FÉRRER   420936.08   242426.67   438359.53   291055.38
# 75             LUCAS BARRETO   324470.43   261886.13   499101.15   299421.62
# 0               ACIR GURGACZ   251714.02   415364.91   415374.00   275816.75
# 51            HUMBERTO COSTA   414626.71   235243.64   419897.20   270687.79
# 42   FERNANDO BEZERRA COELHO   402681.10   280658.76   359317.13   281978.41
# 43           FERNANDO COLLOR   274505.69   406364.87   418023.66   192602.07
# 85            MARCELO CASTRO   356154.62   270555.86   391417.86   260138.16
# 26           DAVI ALCOLUMBRE   129238.22   513609.00   512570.92   119514.77
# 112       RANDOLFE RODRIGUES   336947.98   196151.23   406042.02   291890.71
#
#      SOMA_TOTAL
# 131  1773177.51
# 121  1758934.01
# 94   1734027.59
# 106  1716589.55
# 82   1636389.68
# 118  1566855.17
# 144  1558396.49
# 37   1546998.12
# 32   1544728.09
# 86   1534119.51
# 60   1507560.15
# 129  1500740.09
# 18   1482791.30
# 57   1478912.06
# 100  1462230.18
# 1    1431445.21
# 140  1424522.14
# 88   1410645.25
# 6    1407818.11
# 96   1403904.52
# 141  1396688.41
# 38   1392777.66
# 75   1384879.33
# 0    1358269.68
# 51   1340455.34
# 42   1324635.40
# 43   1291496.29
# 85   1278266.50
# 26   1274932.91
# 112  1231031.94

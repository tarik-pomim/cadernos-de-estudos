# %%
import pandas as pd
from scipy.special import comb

# %% [markdown]
# # **Exercicios Distribuição Binomial:**

# %% [markdown]
# ### **06 Show de prêmios da Alura**

# %% [markdown]
# Suponha que acabamos de criar um jogo de loteria, chamado Show de prêmios da Alura. Neste nosso novo jogo, o apostador marca 20 números, dentre os 25 disponíveis no bilhete, e pode ganhar até 1 milhão de reais.

# %% [markdown]
# Determine qual o número de combinações possíveis (espaço amostral) e a probabilidade de se ganhar o prêmio jogando apenas um bilhete (considere apenas quinze casas decimais).

# %%
combinacoes = comb(25, 20)
probabilidade = 1 / combinacoes
print(f'A probabilidade é de {probabilidade:0.15f} e o numero de combinações possiveis é de {combinacoes}')
# Out:
# A probabilidade é de 0.000018821757952 e o numero de combinações possiveis é de 53130.0

# %% [markdown]
# ### **09 Lançando moedas**

# %% [markdown]
# Uma moeda, perfeitamente equilibrada, é lançada para o alto quatro vezes. Utilizando a distribuição binomial, obtenha a probabilidade de a moeda cair com a face coroa voltada para cima duas vezes.

# %%
# Qual o numero de ensaios (n)? 4 Total de lançamentos
# Qual a probabilidade de sucesso (p)? 1 / 2 (# Probabilidade de sair COROA) = 0.5 (50%)
# Qual a probabilidade de fracasso (q) (q = 1-p)? q = 1 - 0.5 = 0.5
# Qual o total de eventos que se deseja obter sucesso (k)? 2

# %%
# Qual o numero de ensaios (n)? 4 Total de lançamentos
n = 4
n
# Out:
# 4

# %%
# Qual a probabilidade de sucesso (p)? 1 / 2 (# Probabilidade de sair COROA) = 0.5 (50%)
p = 1 / 2
p
# Out:
# 0.5

# %%
# Qual a probabilidade de fracasso (q) (q = 1-p)? q = 1 - 0.5 = 0.5
q = 1 - p
q
# Out:
# 0.5

# %%
# Qual o total de eventos que se deseja obter sucesso (k)? 2 Total de sucessos (faces COROA voltada para cima)
k = 2
k
# Out:
# 2

# %%
from scipy.stats import binom

# %%
probabilidade = binom.pmf(k, n, p)
print(f'{probabilidade:0.8f}')
# Out:
# 0.37500000

# %% [markdown]
# # 10 Lançando dados

# %% [markdown]
# Um dado, perfeitamente equilibrado, é lançado para o alto dez vezes. Utilizando a distribuição binomial, obtenha a probabilidade de o dado cair com o número cinco voltado para cima pelo menos três vezes.

# %%
# Qual o numero de ensaios (n)? 10
# Qual a probabilidade de sucesso (p)? p = 1 / 6
# Qual a probabilidade de fracasso (q) (q = 1-p)?
# Qual o total de eventos que se deseja obter sucesso (k)? 3

# %%
n = 10 # Total de lançamentos
n
# Out:
# 10

# %%
p = 1 / 6  # Probabilidade de sair o número CINCO
p
# Out:
# 0.16666666666666666

# %%
q = 1 - p
q
# Out:
# 0.8333333333333334

# %%
k = 3
k
# Out:
# 3

# %% [markdown]
# A fórmula binom.sf(2, 10, 1/6) é exatamente o cálculo feito em 1 - binom.cdf(2, 10, 1/6), e é por isso que foi utilizado o valor 2. **Como queremos pelo menos 3, basta subtrair a probabilidade acumulada até o valor 2.**

# %%
binom.sf(2, n, p)
# Out:
# 0.22477320212874052

# %% [markdown]
# # **Exercício Média da distribuição binomial:**

# %% [markdown]
# ### 12 Chance de ter olhos azuis

# %% [markdown]
# Suponha que a probabilidade de um casal ter filhos com olhos azuis seja de 22%. Em 50 famílias, com 3 crianças cada uma, quantas podemos esperar que tenham dois filhos com olhos azuis?

# %% [markdown]
# Lembrando:
#
# p = probabilidade de sucesso
#
# q=(1−p) = probabilidade de fracasso
#
# n = número de eventos estudados
#
# k = número de eventos desejados que tenham sucesso

# %% [markdown]
# Usamos a média da distribuição binomial:

# %% [markdown]
# "O valor esperado ou a media da distribuição binomial é igual ao número de experimentos realizados (neste caso, 50) multiplicado pela chance de ocorrencia do evento (neste caso, 11% ou 0.11)

# %%
p = 0.22  # no enunciado já está em %, nao sendo necessario fazer a divisão

# %%
n = 3

# %%
k = 2

# %%
N = 50

# %%
probabilidade = binom.pmf(k, n, p)
print(f'{probabilidade:0.8f}')
# Out:
# 0.11325600

# %%
media_dist_binomial = probabilidade * N
print('Podemos esperar que, em 50 familias com 3 filhos,',
      f'{media_dist_binomial:0.8f} familias tenham dois filhos com olhos azuis.')
# Out:
# Podemos esperar que, em 50 familias com 3 filhos, 5.66280000 familias tenham dois filhos com olhos azuis.

# %% [markdown]
# # **Exercicios Distribuição Poisson:**

# %% [markdown]
# Lembrete:
#
# e  = constante cujo valor aproximado é 2,718281828459045
#
# μ = representa o número médio de ocorrências em um determinado intervalo de tempo ou espaço
#
# k = número de sucessos no intervalo desejado

# %%
from scipy.stats import poisson
import numpy as np
np.e  # Constante de euler citada acima
# Out:
# 2.718281828459045

# %% [markdown]
# ### 05 Estimativa de clientes em determinada hora

# %% [markdown]
# O número médio de clientes que entram em uma padaria por hora é igual a 20. Obtenha a probabilidade de, na próxima hora, entrarem exatamente 25 clientes.

# %%
media = 20

# %%
k = 25

# %%
probabilidade = poisson.pmf(k, media)
print(f'{probabilidade:0.8f}')
# Out:
# 0.04458765

# %% [markdown]
# # Exercícios Distribuição Normal:

# %% [markdown]
# Descobrindo o Z para consultar a tabela normal padronizada:

# %% [markdown]
# Z = (x - media) / desvio_padrao

# %% [markdown]
# x  = variável normal com média μ e desvio padrão σ
#
# σ = desvio padrão
#
# μ = média

# %% [markdown]
# ### 07 Prova de estatística

# %% [markdown]
# A aplicação de uma prova de estatística em um concurso apresentou um conjunto de notas normalmente distribuídas. Verificou-se que o conjunto de notas tinha média 70 e desvio padrão de 5 pontos.
#
# Qual a probabilidade de um aluno, selecionado ao acaso, ter nota menor que 85?

# %%
media = 70

# %%
desvio_padrao = 5

# %%
x = 85

# %%
Z = (x - media) / desvio_padrao
Z
# Out:
# 3.0

# %%
# Verifica o 3.0 na tabela normal padronizada usando scipy:
from scipy.stats import norm
norm.cdf(Z)
# Out:
# 0.9986501019683699

# %%
print('A probabilidade de um aluno, selecionado ao acaso,',
      f'ter nota menor que 85 é de {norm.cdf(Z)}.')
# Out:
# A probabilidade de um aluno, selecionado ao acaso, ter nota menor que 85 é de 0.9986501019683699.

# %% [markdown]
#  ### 09 Faturamento diário

# %% [markdown]
# O faturamento diário de um motorista de aplicativo segue uma distribuição aproximadamente normal, com **média 300,00** e desvio padrão igual a 50,00. Obtenha as probabilidades de que, em um dia aleatório, o motorista ganhe:
#
# 1) Entre 250,00 e 350,00
#
# 2) Entre 400,00 e 500,00

# %% [markdown]
# Z = (x - media) / desvio_padrao

# %% [markdown]
# 1:

# %%
# Z inferior

Z_inferior = (250 - 300) / 50
norm.cdf(Z_inferior)
# Out:
# 0.15865525393145707

# %%
# Z superior

Z_superior = (350 - 300) / 50
norm.cdf(Z_superior)
# Out:
# 0.8413447460685429

# %%
probabilidade = norm.cdf(Z_superior) - norm.cdf(Z_inferior)
round(probabilidade, 4)
# Out:
# 0.6827

# %% [markdown]
# 2:

# %%
# Z inferior

Z_inferior = (400 - 300) / 50
norm.cdf(Z_inferior)
# Out:
# 0.9772498680518208

# %%
# Z superior

Z_superior = (500 - 300) / 50
norm.cdf(Z_superior)
# Out:
# 0.9999683287581669

# %%
probabilidade = norm.cdf(Z_superior) - norm.cdf(Z_inferior)
round(probabilidade, 4)
# Out:
# 0.0227

# %% [markdown]
# ### 11 Vida útil

# %% [markdown]
# O Inmetro verificou que as lâmpadas incandescentes da fabricante XPTO apresentam uma vida útil normalmente distribuída, com **média igual a 720** dias e desvio padrão igual a 30 dias. Calcule a probabilidade de uma lâmpada, escolhida ao acaso, durar:
#
# 1) Entre 650 e 750 dias
#
# 2) Mais que 800 dias
#
# 3) Menos que 700 dias

# %% [markdown]
# Z = (x - media) / desvio_padrao

# %% [markdown]
# 1) Entre 650 e 750 dias:

# %%
Z_superior = (750 - 720) / 30
norm.cdf(Z_superior)
# Out:
# 0.8413447460685429

# %%
Z_inferior = (650 - 720) / 30
norm.cdf(Z_inferior)
# Out:
# 0.009815328628645334

# %%
probabilidade = (norm.cdf(Z_superior)) - (norm.cdf(Z_inferior))
round(probabilidade, 4)
# Out:
# 0.8315

# %% [markdown]
# 2) Mais que 800 dias:

# %%
Z = (800 - 720) / 30
norm.cdf(Z)
# Out:
# 0.9961696194324102

# %%
probabilidade = norm.cdf(-Z)
round(probabilidade, 4)
# Out:
# 0.0038

# %% [markdown]
# 3) Menos que 700 dias:

# %%
Z = (700 - 720) / 30
norm.cdf(Z)
# Out:
# 0.2524925375469229

# %%
probabilidade = norm.cdf(Z)
round(probabilidade, 4)
# Out:
# 0.2525

# %% [markdown]
# ### 12 Obtendo probabilidades

# %% [markdown]
# Utilizando a tabela padronizada, ou o ferramental disponibilizado pelo Python, encontre a área sob a curva normal para os valores de Z abaixo:
#
# 1) Z < 1,96
#
# 2) Z > 2,15
#
# 3) Z < -0,78
#
# 4) Z > 0,59

# %%
# Item 1:
Z = 1.96
norm.cdf(Z)
# Out:
# 0.9750021048517795

# %%
# Item 2:
Z = 2.15
norm.cdf(-Z)
# Out:
# 0.0157776073910905

# %%
# Item 3
Z = -0.78
norm.cdf(Z)
# Out:
# 0.21769543758573312

# %%
# Item 4
Z = 0.59
norm.cdf(Z)
# Out:
# 0.7224046752465351

# %% [markdown]
# Codigo do professor:

# %%
from scipy.stats import norm

# Item A
probabilidade = norm.cdf(1.96)
print("{0:0.4f}".format(probabilidade))

# Item B
probabilidade = 1 - norm.cdf(2.15)
# ou -> probabilidade = norm.sf(2.15)
print("{0:0.4f}".format(probabilidade))

# Item C
probabilidade = norm.cdf(-0.78)
print("{0:0.4f}".format(probabilidade))

# Item D
probabilidade = 1 - norm.cdf(0.59)
# ou -> probabilidade = norm.sf(0.59)
print("{0:0.4f}".format(probabilidade))
# Out:
# 0.9750
# 0.0158
# 0.2177
# 0.2776

# %% [markdown]
# Coloquei um comentário no código para adiantar um assunto que veremos nos próximos treinamentos de estatística. O método sf() de norm serve para obtermos o complemento da probabilidade reportada pelo método cdf(), isto é, norm.sf(Z) = 1 - norm.cdf(Z).

# %% [markdown]
# # Estimação, níveis deconfiança e significância

# %% [markdown]
# ### 07 Margem de erro

# %% [markdown]
# Para estimar o valor médio gasto por cada cliente de uma grande rede de fast-food, foi selecionada uma amostra de 50 clientes.
#
# Assumindo que o valor do desvio padrão da população seja de R$ 6,00 e que esta população se distribui normalmente, obtenha a margem de erro desta estimativa para um nível de confiança de 95%.

# %%
# media_amostra = ?

# %%
significancia = 0.05

# %%
confianca = 1 - significancia
confianca
# Out:
# 0.95

# %%
z = norm.ppf(0.975)
z
# Out:
# 1.959963984540054

# %%
desvio_padrao = 6

# %%
n = 50

# %%
raiz_de_n = np.sqrt(n)
raiz_de_n
# Out:
# 7.0710678118654755

# %%
sigma = desvio_padrao / raiz_de_n
sigma
# Out:
# 0.848528137423857

# %%
e = z * sigma
e
# Out:
# 1.6630845892196133

# %%
# Exemplo da resposta correta:

from scipy.stats import norm
import numpy as np

z = norm.ppf(0.975)
desvio_padrao = 6
n = 50

e = z * (desvio_padrao / np.sqrt(n))
print("R$ {0:0.2f}".format(e))
# Out:
# R$ 1.66

# %% [markdown]
# ### 08 Intervalo de confiança

# %% [markdown]
# Uma amostra aleatória simples de 1976 itens de uma população normalmente distribuída, com desvio padrão populacional igual a 11, resultou em uma média amostral de 28.
#
# Qual o intervalo de confiança de 90% para a média populacional?

# %%
media_amostral = 28

# %%
significancia = 0.10

# %%
confianca = 1 - significancia
confianca
# Out:
# 0.9

# %%
# Utilizando tabelinha de valores de z para os niveis de confianca mais utilizados:

z = norm.ppf(0.95)
z
# Out:
# 1.6448536269514722

# %%
desvio_padrao = 11

# %%
n = 1976

# %%
raiz_de_n = np.sqrt(n)
raiz_de_n
# Out:
# 44.45222154178574

# %%
sigma = desvio_padrao / raiz_de_n
sigma
# Out:
# 0.24745669886621613

# %%
e = z * sigma
e
# Out:
# 0.40703004864353387

# %%
intervalo = (
    media_amostral - e,
    media_amostral + e
)
intervalo
# Out:
# (27.592969951356466, 28.407030048643534)

# %%
# outra forma de calcular:

norm.interval(alpha=0.9, loc=media_amostral, scale=sigma)
# Out:
# (27.592969951356466, 28.407030048643534)

# %%
# codigo da resposta:

from scipy.stats import norm
import numpy as np

media_amostral = 28
desvio_padrao = 11
n = 1976

norm.interval(alpha = 0.90, 
                loc = media_amostral, 
                scale = desvio_padrao / np.sqrt(n))
# Out:
# (27.592969951356466, 28.407030048643534)

# %% [markdown]
# # CÁLCULO DO TAMANHO DA AMOSTRA

# %% [markdown]
# ##Variáveis quantitativas e população infinita

# %% [markdown]
# Com desvio padrão conhecido:
#
# n = (z * (sigma / e)) ** 2

# %% [markdown]
# Com desvio padrão desconhecido:
#
# n = (z * (s / e)) ** 2

# %% [markdown]
# Onde:
#
# z  = variável normal padronizada
#
# sigma  = desvio padrão populacional
#
# s  = desvio padrão amostral
#
# e  = erro inferencial

# %% [markdown]
# Observações
# O desvio padrão ( σ  ou  s ) e o erro ( e ) devem estar na mesma unidade de medida.
#
# Quando o erro ( e ) for representado em termos percentuais, deve ser interpretado como um percentual relacionado à média.

# %% [markdown]
# ## 03 Obtendo o tamanho da amostra

# %% [markdown]
# O valor do gasto médio dos clientes de uma loja de conveniência é de 45,50. Assumindo que o desvio padrão dos gastos é igual a 15,00, qual deve ser o tamanho da amostra para estimarmos a média populacional com um nível de significância de 10%?
#
# Considere que o erro máximo aceitável seja de 10%.

# %%
# significancia 10% == confianca 90%
z = norm.ppf(0.95)
z
# Out:
# 1.6448536269514722

# %%
sigma = 15

# %%
# erro está em % entao 10% da media 45,50
e = 45.5 * 0.10
e
# Out:
# 4.55

# %%
n = (z * (sigma / e)) ** 2
int(n.round())
# Out:
# 29

# %%
# codigo da resposta:
from scipy.stats import norm

media = 45.5
sigma = 15
significancia = 0.10
confianca = 1 - significancia

z = norm.ppf(0.5 + (confianca / 2))
erro_percentual = 0.10
e = media * erro_percentual

n = (z * (sigma / e)) ** 2
n.round()
# Out:
# 29.0

# %% [markdown]
# O tamanho da amostra deve ser de aproximadamente 29 clientes.

# %% [markdown]
# # Variáveis quantitativas e população finita

# %%
# Desvio padrao desconhecido:
# n = ((z**2) * (s**2) * (N)) / (((z**2) * (s**2)) + ((e**2) * (N - 1)))

# Desvio padrao conhecido:
# n = ((z**2) * (sigma**2) * (N)) / (((z**2) * (sigma**2)) + ((e**2) * (N - 1)))

# um é o s em outro é o sigma

# %% [markdown]
# Onde:
#
# N  = tamanho da população e não da amostra
#
# z  = variável normal padronizada
#
# sigma  = desvio padrão populacional
#
# s  = desvio padrão amostral
#
# e  = erro inferencial

# %% [markdown]
# ### 05 Amostra de sacos de farinha

# %% [markdown]
# Um fabricante de farinha verificou que, em uma amostra aleatória formada por 200 sacos de 25 kg de um lote formado por 2.000 sacos, apresentou um desvio padrão amostral do peso igual a 480 g.
#
# Considerando um erro máximo associado à média populacional igual a 0,3 kg e um nível de confiança igual a 95%, qual tamanho de amostra deveria ser selecionado para obtermos uma estimativa confiável do parâmetro populacional?

# %%
N = 2000

# %%
z = norm.ppf(0.975)

# %%
s = 0.480

# %%
e = 0.3

# %%
n = ((z**2) * (s**2) * (N)) / (((z**2) * (s**2)) + ((e**2) * (N - 1)))
int(round(n))
# Out:
# 10

# %% [markdown]
# O tamanho de amostra deveria ser selecionado para obtermos uma estimativa confiável do parâmetro populacional é de 10 sacos.
